# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./survey_results_public.csv')
schema=pd.read_csv('./survey_results_schema.csv')

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
schema
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.tail(10)
# Out:
#        Respondent MainBranch Hobbyist  \
# 88873       88062        NaN       No
# 88874       88076        NaN       No
# 88875       88182        NaN      Yes
# 88876       88212        NaN       No
# 88877       88282        NaN      Yes
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88873                                              Never
# 88874                                              Never
# 88875                         Once a month or more often
# 88876                            Less than once per year
# 88877                         Once a month or more often
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# ...

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df.loc[0]
# Out:
# Respondent                                                                1
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# ...

# %%
df.loc[0,'Hobbyist']
# Out:
# 'Yes'

# %%
df.loc[[0,3,10],'Hobbyist']
# Out:
# 0     Yes
# 3      No
# 10    Yes
# Name: Hobbyist, dtype: object

# %%
df.loc[0:10,'Hobbyist']
# Out:
# 0     Yes
# 1      No
# 2     Yes
# 3      No
# 4     Yes
# 5     Yes
# 6      No
# 7     Yes
# 8     Yes
# 9     Yes
# 10    Yes
# Name: Hobbyist, dtype: object

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.loc[0:10,['Hobbyist','LanguageWorkedWith']]
# Out:
#    Hobbyist                                 LanguageWorkedWith
# 0       Yes                    HTML/CSS;Java;JavaScript;Python
# 1        No                                C++;HTML/CSS;Python
# 2       Yes                                           HTML/CSS
# 3        No                                C;C++;C#;Python;SQL
# 4       Yes        C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 5       Yes                                         Java;R;SQL
# 6        No                                HTML/CSS;JavaScript
# 7       Yes  Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 8       Yes  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 9       Yes                      C#;Go;JavaScript;Python;R;SQL
# 10      Yes                                          Other(s):

# %%
df.loc[0:3,['Hobbyist','Employment']]
# Out:
#   Hobbyist                              Employment
# 0      Yes  Not employed, and not looking for work
# 1       No      Not employed, but looking for work
# 2      Yes                      Employed full-time
# 3       No                      Employed full-time

# %% [markdown]
# # Ch 4 Filtering

# %%
high_salary = (df['ConvertedComp'] > 70000)

# %%
df.loc[high_salary, ['Country','LanguageWorkedWith', 'ConvertedComp']]
# Out:
#               Country                                 LanguageWorkedWith  \
# 5              Canada                                         Java;R;SQL
# 8         New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 12      United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 15     United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 21      United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...               ...                                                ...
# 88323   United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88324   United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88325   United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88326         Finland                   Bash/Shell/PowerShell;C++;Python
# 88329     Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
#        ConvertedComp
# 5           366420.0
# 8            95179.0
# 12           90000.0
# ...

# %%
countries =['United States', 'Mexico', 'India', 'United Kingdom', 'Canada']
filt = df['Country'].isin(countries)

# %%
df.loc[filt, 'Country']
# Out:
# 0        United Kingdom
# 3         United States
# 5                Canada
# 7                 India
# 9                 India
#               ...
# 88859     United States
# 88863    United Kingdom
# 88864             India
# 88877     United States
# 88878            Canada
# Name: Country, Length: 39784, dtype: object

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filt,'LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 7        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 88854    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 88860      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 88865      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 88872             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88876                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %% [markdown]
# # Part 5 Updating Rows and Columns - Modifying Data Within DataFrames

# %%
df.rename(columns={'ConvertedComp': 'SalaryUSD'}, inplace=True)
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'SalaryUSD', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['SalaryUSD']
# Out:
# 0            NaN
# 1            NaN
# 2         8820.0
# 3        61000.0
# 4            NaN
#           ...
# 88878        NaN
# 88879        NaN
# 88880        NaN
# 88881        NaN
# 88882        NaN
# Name: SalaryUSD, Length: 88883, dtype: float64

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist']= df['Hobbyist'].map({'Yes':True, 'No':False})

# %%
df['Hobbyist']
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 88878     True
# 88879    False
# 88880    False
# 88881    False
# 88882     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %% [markdown]
# # Part 7: Sorting Data

# %%
df.sort_values(by='Country', inplace=True)
df
# Out:
#        Respondent                      MainBranch  Hobbyist  \
# 39018       39258  I am a developer by profession      True
# 62723       63129  I am a developer by profession      True
# 85185       85715  I am a developer by profession     False
# 50437       50767  I am a developer by profession     False
# 88340        2782                             NaN      True
# ...           ...                             ...       ...
# 88873       88062                             NaN     False
# 88874       88076                             NaN     False
# 88879       88601                             NaN     False
# 88880       88802                             NaN     False
# 88881       88816                             NaN     False
#
#                    OpenSourcer  \
# 39018  Less than once per year
# 62723                    Never
# 85185  Less than once per year
# 50437  Less than once per year
# 88340  Less than once per year
# ...                        ...
# ...

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'SalaryUSD', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df[['Country','SalaryUSD']]
# Out:
#            Country  SalaryUSD
# 39018  Afghanistan    19152.0
# 62723  Afghanistan  1000000.0
# 85185  Afghanistan        NaN
# 50437  Afghanistan        NaN
# 88340  Afghanistan        NaN
# ...            ...        ...
# 88873          NaN        NaN
# 88874          NaN        NaN
# 88879          NaN        NaN
# 88880          NaN        NaN
# 88881          NaN        NaN
#
# [88883 rows x 2 columns]

# %%
df.sort_values(by=['Country', 'SalaryUSD'], ascending=[True, False], inplace=True)
df[['Country','SalaryUSD']].head(80)
# Out:
#            Country  SalaryUSD
# 62723  Afghanistan  1000000.0
# 50172  Afghanistan   153216.0
# 39018  Afghanistan    19152.0
# 58082  Afghanistan    17556.0
# 7056   Afghanistan    14364.0
# 22327  Afghanistan     7980.0
# 48122  Afghanistan     4464.0
# 10697  Afghanistan     3996.0
# 8112   Afghanistan     1596.0
# 29560  Afghanistan     1116.0
# 28470  Afghanistan        0.0
# 719    Afghanistan        0.0
# 85185  Afghanistan        NaN
# 50437  Afghanistan        NaN
# 88340  Afghanistan        NaN
# 88735  Afghanistan        NaN
# 6391   Afghanistan        NaN
# 39754  Afghanistan        NaN
# 88181  Afghanistan        NaN
# 62124  Afghanistan        NaN
# 49377  Afghanistan        NaN
# 32971  Afghanistan        NaN
# 60559  Afghanistan        NaN
# 85827  Afghanistan        NaN
# 88033  Afghanistan        NaN
# 26189  Afghanistan        NaN
# 86394  Afghanistan        NaN
# 85293  Afghanistan        NaN
# 7323   Afghanistan        NaN
# 86551  Afghanistan        NaN
# ...

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# 25833    2000000.0
# 87353    2000000.0
# 21895    2000000.0
# 28080    2000000.0
# 72274    2000000.0
# 77665    2000000.0
# 79701    2000000.0
# 51798    2000000.0
# 75088    2000000.0
# 32056    2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(10, 'SalaryUSD')
# Out:
#        Respondent                                         MainBranch  \
# 25833       25983                     I am a developer by profession
# 87353       87896                     I am a developer by profession
# 21895       22013                     I am a developer by profession
# 28080       28243                     I am a developer by profession
# 72274       72732  I am not primarily a developer, but I write co...
# 77665       78151                     I am a developer by profession
# 79701       80200                     I am a developer by profession
# 51798       52132                     I am a developer by profession
# 75088       75561                     I am a developer by profession
# 32056       32250                     I am a developer by profession
#
#        Hobbyist                                        OpenSourcer  \
# 25833      True                            Less than once per year
# 87353      True                            Less than once per year
# ...

# %% [markdown]
# # Part 8: Grouping and Aggregating - Analyzing and Exploring Your Data

# %%
df['SalaryUSD'].head(15)
# Out:
# 62723    1000000.0
# 50172     153216.0
# 39018      19152.0
# 58082      17556.0
# 7056       14364.0
# 22327       7980.0
# 48122       4464.0
# 10697       3996.0
# 8112        1596.0
# 29560       1116.0
# 28470          0.0
# 719            0.0
# 85185          NaN
# 50437          NaN
# 88340          NaN
# Name: SalaryUSD, dtype: float64

# %%
df['SalaryUSD'].median()
# Out:
# 57287.0

# %%
df.median()
# Out:
# C:\Users\Usuario Innova\AppData\Local\Temp\ipykernel_7560\530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Respondent     44442.0
# Hobbyist           1.0
# CompTotal      62000.0
# SalaryUSD      57287.0
# WorkWeekHrs       40.0
# CodeRevHrs         4.0
# Age               29.0
# dtype: float64

# %%
df.describe()
# Out:
#          Respondent     CompTotal     SalaryUSD   WorkWeekHrs    CodeRevHrs  \
# count  88883.000000  5.594500e+04  5.582300e+04  64503.000000  49790.000000
# mean   44442.000000  5.519014e+11  1.271107e+05     42.127197      5.084308
# std    25658.456325  7.331926e+13  2.841523e+05     37.287610      5.513931
# min        1.000000  0.000000e+00  0.000000e+00      1.000000      0.000000
# 25%    22221.500000  2.000000e+04  2.577750e+04     40.000000      2.000000
# 50%    44442.000000  6.200000e+04  5.728700e+04     40.000000      4.000000
# 75%    66662.500000  1.200000e+05  1.000000e+05     44.750000      6.000000
# max    88883.000000  1.000000e+16  2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
df['Hobbyist'].value_counts()
# Out:
# True     71257
# False    17626
# Name: Hobbyist, dtype: int64

# %%
df['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
sm = df['SocialMedia'].value_counts(normalize=True)
sm
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
sm2 = pd.DataFrame(sm)
sm2
# Out:
#                           SocialMedia
# Reddit                       0.170233
# YouTube                      0.163791
# WhatsApp                     0.158071
# Facebook                     0.156069
# Twitter                      0.134988
# Instagram                    0.074150
# I don't use social media     0.065777
# LinkedIn                     0.053306
# WeChat 微信                    0.007899
# Snapchat                     0.007437
# VK ВКонта́кте                0.007141
# Weibo 新浪微博                   0.000663
# Youku Tudou 优酷               0.000249
# Hello                        0.000225

# %%
s3= sm2.reset_index()
s3
# Out:
#                        index  SocialMedia
# 0                     Reddit     0.170233
# 1                    YouTube     0.163791
# 2                   WhatsApp     0.158071
# 3                   Facebook     0.156069
# 4                    Twitter     0.134988
# 5                  Instagram     0.074150
# 6   I don't use social media     0.065777
# 7                   LinkedIn     0.053306
# 8                  WeChat 微信     0.007899
# 9                   Snapchat     0.007437
# 10             VK ВКонта́кте     0.007141
# 11                Weibo 新浪微博     0.000663
# 12            Youku Tudou 优酷     0.000249
# 13                     Hello     0.000225

# %%
s3.columns
# Out:
# Index(['index', 'SocialMedia'], dtype='object')

# %%
s3 = s3.rename(columns={'index': 'SMedia', 'SocialMedia': 'Porcentaje'})
s3.set_index('SMedia', inplace=True)

# %%
s3.plot(kind='bar')
plt.show()
# Out:
# C:\Users\Usuario Innova\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 24494 (\N{CJK UNIFIED IDEOGRAPH-5FAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Usuario Innova\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20449 (\N{CJK UNIFIED IDEOGRAPH-4FE1}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Usuario Innova\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 26032 (\N{CJK UNIFIED IDEOGRAPH-65B0}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Usuario Innova\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 28010 (\N{CJK UNIFIED IDEOGRAPH-6D6A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
df['Country'].value_counts(normalize=True)
# Out:
# United States                       0.236042
# India                               0.102095
# Germany                             0.066095
# United Kingdom                      0.064642
# Canada                              0.038253
#                                       ...
# North Korea                         0.000011
# Niger                               0.000011
# Saint Vincent and the Grenadines    0.000011
# Chad                                0.000011
# Brunei Darussalam                   0.000011
# Name: Country, Length: 179, dtype: float64

# %%
df['Country'].value_counts(normalize=True).nlargest(10).plot(kind='barh')
# Out:
# <Axes: >

# %%
df.groupby(['Country']).count()
# Out:
#                                       Respondent  MainBranch  Hobbyist  \
# Country
# Afghanistan                                   44          42        44
# Albania                                       86          85        86
# Algeria                                      134         129       134
# Andorra                                        7           7         7
# Angola                                         5           5         5
# ...                                          ...         ...       ...
# Venezuela, Bolivarian Republic of...          88          88        88
# Viet Nam                                     231         227       231
# Yemen                                         19          19        19
# Zambia                                        12          12        12
# Zimbabwe                                      39          39        39
#
#                                       OpenSourcer  OpenSource  Employment  \
# Country
# ...

# %%
country_grp=df.groupby(['Country'])
country_grp.get_group('United States')
# Out:
#        Respondent                      MainBranch  Hobbyist  \
# 2927         2940  I am a developer by profession      True
# 3119         3133  I am a developer by profession      True
# 78468       78960  I am a developer by profession      True
# 3106         3120  I am a developer by profession      True
# 78362       78853  I am a developer by profession     False
# ...           ...                             ...       ...
# 32602       32801  I am a developer by profession     False
# 32612       32811  I am a developer by profession     False
# 32686       32886  I am a developer by profession     False
# 68166       68604  I am a developer by profession      True
# 33583       33792  I am a developer by profession      True
#
#                                              OpenSourcer  \
# 2927                                               Never
# 3119                                               Never
# 78468                            Less than once per year
# ...

# %%
f = df['Country'] == 'United States'
df.loc[f]
# Out:
#        Respondent                      MainBranch  Hobbyist  \
# 2927         2940  I am a developer by profession      True
# 3119         3133  I am a developer by profession      True
# 78468       78960  I am a developer by profession      True
# 3106         3120  I am a developer by profession      True
# 78362       78853  I am a developer by profession     False
# ...           ...                             ...       ...
# 32602       32801  I am a developer by profession     False
# 32612       32811  I am a developer by profession     False
# 32686       32886  I am a developer by profession     False
# 68166       68604  I am a developer by profession      True
# 33583       33792  I am a developer by profession      True
#
#                                              OpenSourcer  \
# 2927                                               Never
# 3119                                               Never
# 78468                            Less than once per year
# ...

# %%
df.loc[f]['SocialMedia'].value_counts()
# Out:
# Reddit                      5700
# Twitter                     3468
# Facebook                    2844
# YouTube                     2463
# I don't use social media    1851
# Instagram                   1652
# LinkedIn                    1020
# WhatsApp                     609
# Snapchat                     326
# WeChat 微信                     93
# VK ВКонта́кте                  9
# Weibo 新浪微博                     8
# Hello                          2
# Youku Tudou 优酷                 1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().head(80)
# Out:
# Country              SocialMedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# ...

# %%
country_grp['SocialMedia'].value_counts().loc['Mexico']
# Out:
# SocialMedia
# WhatsApp                    168
# Facebook                    138
# Twitter                      96
# YouTube                      96
# Reddit                       55
# Instagram                    40
# I don't use social media     15
# LinkedIn                     10
# Snapchat                      1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts(normalize=True).loc['China']*100
# Out:
# SocialMedia
# WeChat 微信                   67.054908
# YouTube                      8.818636
# Weibo 新浪微博                   6.988353
# I don't use social media     4.492512
# Twitter                      4.492512
# Reddit                       1.996672
# LinkedIn                     1.830283
# Facebook                     1.331115
# Instagram                    1.164725
# Youku Tudou 优酷               1.164725
# WhatsApp                     0.499168
# VK ВКонта́кте                0.166389
# Name: SocialMedia, dtype: float64

# %%
country_grp['SalaryUSD'].median().head(100)
# Out:
# Country
# Afghanistan      6222.0
# Albania         10818.0
# Algeria          7878.0
# Andorra        160931.0
# Angola           7764.0
#                  ...
# Malaysia        16890.0
# Maldives        13938.0
# Mali            10476.0
# Malta           46976.0
# Mauritania          NaN
# Name: SalaryUSD, Length: 100, dtype: float64

# %%
country_grp['SalaryUSD'].median().loc['Germany']
# Out:
# 63016.0

# %%
country_grp['SalaryUSD'].median().nlargest(10)
# Out:
# Country
# Liechtenstein                       811188.0
# San Marino                          301788.0
# Timor-Leste                         229500.0
# Andorra                             160931.0
# Democratic Republic of the Congo    110484.0
# United States                       110000.0
# Switzerland                          95440.0
# Israel                               90720.0
# Ireland                              83640.0
# Denmark                              82860.0
# Name: SalaryUSD, dtype: float64

# %%
country_grp['SalaryUSD'].median().nsmallest(10)
# Out:
# Country
# Gabon                      0.0
# Guinea                  1956.0
# Sudan                   2016.0
# Syrian Arab Republic    2742.0
# Burundi                 3606.0
# Cuba                    3666.0
# Madagascar              4074.0
# Togo                    4188.0
# Nepal                   4224.0
# Myanmar                 4806.0
# Name: SalaryUSD, dtype: float64

# %%
country_grp['SalaryUSD'].agg(['median', 'mean']).loc[['Togo','Nepal']]
# Out:
#          median          mean
# Country
# Togo     4188.0   4188.000000
# Nepal    4224.0  10434.987952

# %%
f = df['Country'] == 'Spain'
df.loc[f]['LanguageWorkedWith'].str.contains('Python').value_counts()
# Out:
# False    947
# True     641
# Name: LanguageWorkedWith, dtype: int64

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum()).sort_values(ascending=False)
# Out:
# Country
# United States     10083
# India              3105
# Germany            2451
# United Kingdom     2384
# Canada             1558
#                   ...
# Malawi                0
# Tonga                 0
# Djibouti              0
# Liberia               0
# Cape Verde            0
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country_grp['LanguageWorkedWith'].apply( lambda x: x.str.contains('Python').sum() / len(x) * 100 ).nlargest(30)
# Out:
# Country
# Dominica                     100.000000
# Niger                        100.000000
# Sao Tome and Principe        100.000000
# Timor-Leste                  100.000000
# Turkmenistan                  85.714286
# Mauritania                    71.428571
# Bahamas                       66.666667
# Guinea                        66.666667
# Guyana                        66.666667
# Uganda                        65.277778
# Iceland                       61.224490
# Benin                         60.000000
# Haiti                         60.000000
# Namibia                       60.000000
# Congo, Republic of the...     57.142857
# Oman                          54.545455
# Cuba                          53.333333
# Republic of Korea             51.282051
# Bhutan                        50.000000
# Monaco                        50.000000
# San Marino                    50.000000
# Seychelles                    50.000000
# Sierra Leone                  50.000000
# ...

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').value_counts())
# Out:
# Country
# Afghanistan  False    31
#              True      8
# Albania      False    60
#              True     23
# Algeria      False    86
#                       ..
# Yemen        True      3
# Zambia       False     8
#              True      4
# Zimbabwe     False    25
#              True     14
# Name: LanguageWorkedWith, Length: 335, dtype: int64

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# North Korea                             1
# Niger                                   1
# Saint Vincent and the Grenadines        1
# Chad                                    1
# Brunei Darussalam                       1
# Name: Country, Length: 179, dtype: int64

# %%
country_uses_python=country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_pd = pd.concat([country_respondents, country_uses_python], axis='columns', sort=False)
python_pd
# Out:
#                                   Country  LanguageWorkedWith
# United States                       20949               10083
# India                                9061                3105
# Germany                              5866                2451
# United Kingdom                       5737                2384
# Canada                               3395                1558
# ...                                   ...                 ...
# North Korea                             1                   0
# Niger                                   1                   1
# Saint Vincent and the Grenadines        1                   0
# Chad                                    1                   0
# Brunei Darussalam                       1                   0
#
# [179 rows x 2 columns]

# %%
python_pd.rename(columns={'Country': 'Total', 'LanguageWorkedWith':'Python_Tot'}, inplace=True)

# %%
python_pd
# Out:
#                                   Total  Python_Tot
# United States                     20949       10083
# India                              9061        3105
# Germany                            5866        2451
# United Kingdom                     5737        2384
# Canada                             3395        1558
# ...                                 ...         ...
# North Korea                           1           0
# Niger                                 1           1
# Saint Vincent and the Grenadines      1           0
# Chad                                  1           0
# Brunei Darussalam                     1           0
#
# [179 rows x 2 columns]

# %%
python_pd['PythonPct']= python_pd['Python_Tot']*100/python_pd['Total']

# %%
python_pd.nlargest(columns='Total',n=20)
# Out:
#                     Total  Python_Tot  PythonPct
# United States       20949       10083  48.131176
# India                9061        3105  34.267741
# Germany              5866        2451  41.783157
# United Kingdom       5737        2384  41.554820
# Canada               3395        1558  45.891016
# France               2391        1054  44.081974
# Brazil               1948         767  39.373717
# Poland               1922         751  39.073881
# Australia            1903         790  41.513400
# Netherlands          1852         767  41.414687
# Russian Federation   1694         708  41.794569
# Spain                1604         641  39.962594
# Italy                1576         625  39.657360
# Sweden               1274         496  38.932496
# Switzerland           978         460  47.034765
# Israel                952         457  48.004202
# Turkey                949         371  39.093783
# Pakistan              923         251  27.193933
# ...

# %%
python_pd.loc['Mexico']
# Out:
# Total         642.000000
# Python_Tot    245.000000
# PythonPct      38.161994
# Name: Mexico, dtype: float64

# %% [markdown]
# # Part 9: Cleaning Data - Casting Datatypes and Handling Missing Values

# %%
df['YearsCode'].unique()
# Out:
# array(['Less than 1 year', '7', '2', '6', '3', '4', '10', '36', '8', nan,
#        '1', '20', '28', '31', '9', '5', 'More than 50 years', '15', '13',
#        '12', '17', '18', '35', '14', '21', '25', '11', '19', '22', '23',
#        '40', '39', '30', '43', '27', '33', '29', '24', '34', '16', '26',
#        '32', '38', '44', '45', '41', '37', '47', '42', '46', '48', '49',
#        '50'], dtype=object)

# %%
df['YearsCode'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Gonzalo\g\Pandas\CoreySchafer.ipynb Cell 78 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Gonzalo/g/Pandas/CoreySchafer.ipynb#Y140sZmlsZQ%3D%3D?line=0'>1</a> df['YearsCode'].mean()
#
# File c:\Python310\lib\site-packages\pandas\core\generic.py:11847, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11829 @doc(
#   11830     _num_doc,
#   11831     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11845     **kwargs,
#   11846 ):
# > 11847     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File c:\Python310\lib\site-packages\pandas\core\generic.py:11401, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11393 def mean(
#   11394     self,
# ...

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)
df['YearsCode'].unique()
# Out:
# array([0, '7', '2', '6', '3', '4', '10', '36', '31', '9', '5',
#        'More than 50 years', nan, '8', '1', '20', '28', '15', '13', '12',
#        '17', '18', '21', '14', '35', '25', '11', '19', '22', '23', '40',
#        '39', '30', '43', '27', '33', '29', '24', '34', '16', '26', '32',
#        '38', '44', '45', '41', '37', '47', '42', '46', '48', '50', '49'],
#       dtype=object)

# %%
df['YearsCode'].replace('More than 50 years', 51, inplace=True)
df['YearsCode'].unique()
# Out:
# array([0, '7', '2', '6', '3', '4', '10', '36', '31', '9', '5', 51, nan,
#        '8', '1', '20', '28', '15', '13', '12', '17', '18', '21', '14',
#        '35', '25', '11', '19', '22', '23', '40', '39', '30', '43', '27',
#        '33', '29', '24', '34', '16', '26', '32', '38', '44', '45', '41',
#        '37', '47', '42', '46', '48', '50', '49'], dtype=object)

# %%
df['YearsCode'].dtypes
# Out:
# dtype('O')

# %%
df['YearsCode'] = df['YearsCode'].astype(float)
df['YearsCode'].dtypes
# Out:
# dtype('float64')

# %%
df['YearsCode'].mean()
# Out:
# 11.662114216834588

# %%
df['YearsCode'].median()
# Out:
# 9.0

# %%
df['YearsCode'].mode()
# Out:
# 0    5.0
# Name: YearsCode, dtype: float64

# %%
df['YearsCode'].isna().value_counts()
# Out:
# False    87938
# True       945
# Name: YearsCode, dtype: int64

# %% [markdown]
# # Part 11: Reading/Writing Data to Different Sources - Excel, JSON, SQL, Etc

# %%
f = (df['Country'] == 'India')
df_india= df.loc[f]

# %%
df_india.to_csv('./india.csv')

# %%
df_india.to_csv('./india.tsv', sep='\t')

# %%
df_india.to_excel('./india.xlsx')

# %%
df_india.to_json('./india.json', orient='records', lines=True)
