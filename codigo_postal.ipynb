# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandasql import sqldf

# %%
df = pd.read_excel('./Veracruz_CPs.xlsx')
df.sample(10)
# Out:
# c:\Python310\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#        d_codigo               d_asenta d_tipo_asenta                D_mnpio  \
# 8837      96300          Fidel Herrera       Colonia               Jáltipan
# 10036     96997         Paso del Moral  Congregación               Uxpanapa
# 4615      94290             Pescadores       Colonia           Boca del Río
# 4864      94430  Ixhuatlancillo Centro       Colonia         Ixhuatlancillo
# 2910      92994             Buenavista       Colonia     Cazones de Herrera
# 4005      93894            Las Paredes       Colonia           Chiconquiaco
# 1896      92270              Ixcatepec        Pueblo              Ixcatepec
# 7618      95694               La Bomba        Barrio   Juan Rodríguez Clara
# 8661      96130            Cascajalito     Ranchería   San Juan Evangelista
# 868       91620          Piedra Parada  Congregación  Cosautlán de Carvajal
#
#                               d_estado              d_ciudad   d_CP  c_estado  \
# 8837   Veracruz de Ignacio de la Llave                   NaN  96201        30
# 10036  Veracruz de Ignacio de la Llave                   NaN  96997        30
# 4615   Veracruz de Ignacio de la Llave          Boca del Río  94292        30
# 4864   Veracruz de Ignacio de la Llave                   NaN  94301        30
# 2910   Veracruz de Ignacio de la Llave                   NaN  92981        30
# 4005   Veracruz de Ignacio de la Llave                   NaN  91401        30
# 1896   Veracruz de Ignacio de la Llave                   NaN  92301        30
# 7618   Veracruz de Ignacio de la Llave  Juan Rodríguez Clara  95691        30
# 8661   Veracruz de Ignacio de la Llave                   NaN  96121        30
# 868    Veracruz de Ignacio de la Llave                   NaN  91616        30
#
#        c_oficina  c_CP  c_tipo_asenta  c_mnpio  id_asenta_cpcons      d_zona  \
# 8837       96201   NaN              9       89              8700       Rural
# 10036      96997   NaN             11      210              7506       Rural
# 4615       94292   NaN              9       28              4303      Urbano
# 4864       94301   NaN              9       81              5332       Rural
# 2910       92981   NaN              9       33                19       Rural
# 4005       91401   NaN              9       57              2613       Rural
# 1896       92301   NaN             28       78              1365       Rural
# 7618       95691   NaN              2       94               859  Semiurbano
# 8661       96121   NaN             29      142              6301       Rural
# 868        91616   NaN             11       46               402       Rural
#
#        c_cve_ciudad
# 8837            NaN
# 10036           NaN
# 4615            3.0
# 4864            NaN
# 2910            NaN
# 4005            NaN
# 1896            NaN
# 7618           27.0
# 8661            NaN
# 868             NaN

# %%
cp_veracruz =df[['d_codigo', 'd_asenta', 'd_ciudad']]
cp_veracruz.sample(5)
# Out:
#       d_codigo                d_asenta              d_ciudad
# 3365     93570  Rafael Hernandez Ochoa                   NaN
# 5212     94580              Las Palmas               Córdoba
# 4914     94462            Valle Alegre        Ixtaczoquitlán
# 4972     94475              Jacarandas  Fortín de las Flores
# 4783     94380          Heriberto Jara               Orizaba

# %%
cp_veracruz['d_ciudad']=cp_veracruz['d_ciudad'].str.upper()
cp_veracruz
# Out:
# C:\Users\Usuario Innova\AppData\Local\Temp\ipykernel_25312\3073458185.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cp_veracruz['d_ciudad']=cp_veracruz['d_ciudad'].str.upper()
#        d_codigo                               d_asenta         d_ciudad
# 0         91000                 Xalapa Enríquez Centro  XALAPA-ENRÍQUEZ
# 1         91010                            21 de Marzo  XALAPA-ENRÍQUEZ
# 2         91010                         Del Periodista  XALAPA-ENRÍQUEZ
# 3         91010                           Arroyo Zarco  XALAPA-ENRÍQUEZ
# 4         91010                            18 de Marzo  XALAPA-ENRÍQUEZ
# ...         ...                                    ...              ...
# 10079     96998           Nuevo Cantón (Poblado Siete)              NaN
# 10080     96998                          Nuevo Córdoba              NaN
# 10081     96998  Juan Rodríguez Clara (Álvaro Obregón)              NaN
# 10082     96998      Colonia del Valle (Poblado Trece)              NaN
# 10083     96998                          Poblado Cinco              NaN
#
# [10084 rows x 3 columns]

# %%
pd.options.display.max_columns=None

# %%
df2 = pd.read_excel('./BURO_HUATUSCO_31052023.xlsx')
df2.sample(3)
# Out:
# c:\Python310\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#      INTF  VERSION CLAVE_OTORGANTE_1 NOMBRE DEL OTORGANTE_1 RESERVADO  \
# 158  INTF       14        MI99991111       HUATUSCO
# 466  INTF       14        MI99991111       HUATUSCO
# 499  INTF       14        MI99991111       HUATUSCO
#
#      FECHA DE REPORTE  RESERVADO_2 APELLIDO_PATERNO APELLIDO_MATERNO  \
# 158          31052023            0          SERRANO            LOPEZ
# 466          31052023            0             RUIZ            LOPEZ
# 499          31052023            0        CONTRERAS          SANCHEZ
#
#      APELLIDO_ADICIONAL PRIMER_NOMBRE SEGUNDO_NOMBRE  FECHA_NACIMIENTO  \
# 158                 NaN         ROCIO             00          18011991
# 466                 NaN         PAULA             00           2031974
# 499                 NaN       LETICIA             00           2081974
#
#                RFC PREFIJO  SUFIJO NACIONALIDAD  TIPO_DE_RESIDENCIA  \
# 158  SELR910118VE8     SRA     NaN           MX                   2
# 466  RULP740302DMA     SRA     NaN           MX                   2
# 499  COSL7408023J5     SRA     NaN           MX                   1
#
#      NUM_LICENCIA_CONDUCIR ESTADO_CIVIL SEXO  NUMERO_SEGURIDAD_SOCIAL  \
# 158                    NaN            F    F                      NaN
# 466                    NaN            M    F                      NaN
# 499                    NaN            M    F                      NaN
#
#          FOLIO_INE           CLAVE_INE                CURP CLAVE_PAIS  \
# 158                                     SELR910118MVZRPC06         MX
# 466                                     RULP740302MVZZPL09         MX
# 499  4095038994728  CNSNLT74080230M400  COSL740802MVZNNT01         MX
#
#      NUMERO_DEPENDIENTES  EDADES_DEPENDIENTES  FECHA_DEFUNCIÓN  \
# 158                    0                    0          1011900
# 466                    0                    0          1011900
# 499                    0                    0          1011900
#
#     INDICADOR_DEFUNCIÓN                                    PA  \
# 158                          COLONIA BARRIOS TOTUTLA VERACRUZ
# 466                      FTE TELESECUNDARIA MATA DE INDIO VER
# 499                                   C GUADALUPE VICTORIA SN
#
#     DIRECCION_COMPLEMENTO COLONIA_O_POBLACIÓN DELEGACIÓN_O_MUNICIPIO   CIUDAD  \
# 158                   NaN             TOTUTLA                TOTUTLA  TOTUTLA
# 466                   NaN       MATA DE INDIO                TOTUTLA  TOTUTLA
# 499                   NaN       MATA DE INDIO                TOTUTLA  TOTUTLA
#
#     CLAVE_ESTADO  CODIGO_POSTAL  FECHA_RESIDENCIA    TELÉFONO  EXTENSIÓN_TEL  \
# 158          VER          94050               NaN  2731110773            NaN
# 466          VER          94050               NaN  2731012352            NaN
# 499          VER          94059               NaN  2282512589            NaN
#
#      FAX  TIPO_DOMICILIO  INDICADOR_DOMICILIO PAIS_DOMICILIO  \
# 158  NaN             NaN                  NaN             MX
# 466  NaN             NaN                  NaN             MX
# 499  NaN             NaN                  NaN             MX
#
#                            PE  DIRECCION_TRABAJO  \
# 158  TRABAJADOR INDEPENDIENTE        LOC TOTUTLA
# 466  TRABAJADOR INDEPENDIENTE  LOC MATA DE INDIO
# 499  TRABAJADOR INDEPENDIENTE      MATA DE INDIO
#
#     DIRECCION_TRABAJO_COMPLEMENTO COLONIA_TRABAJO MUNICIPIO_TRABAJO  \
# 158                           NaN         TOTUTLA           TOTUTLA
# 466                           NaN   MATA DE INDIO           TOTUTLA
# 499                           NaN   MATA DE INDIO           TOTUTLA
#
#     CIUDAD_TRABAJO ESTADO_TRABAJO  CODIGO_POSTAL_TRABAJO TELEFONO_TRABAJO  \
# 158        TOTUTLA            VER                  94050       0000000000
# 466        TOTUTLA            VER                  94050       0000000000
# 499        TOTUTLA            VER                  94059       0000000000
#
#      EXT_TEL_TRABAJO  FAX_TRABAJO  \
# 158              NaN          NaN
# 466              NaN          NaN
# 499              NaN          NaN
#
#                                              OCUPACION  FECHA_CONTRATACION  \
# 158  COMERCIANTE                                   ...                 NaN
# 466  COMERCIANTE                                   ...                 NaN
# 499  CAMPESINO                                     ...                 NaN
#
#      MONEDA_PAGO  SUELDO_SALARIO  PERIODO_PAGO  NUMERO_EMPLEADO  \
# 158          NaN             NaN           NaN              NaN
# 466          NaN             NaN           NaN              NaN
# 499          NaN             NaN           NaN              NaN
#
#      FECHA_UD_EMPLEO  FECHA_VERIFICACION_EMPLEO PAIS_EMPLEO  TL  \
# 158              NaN                        NaN          MX  TL
# 466              NaN                        NaN          MX  TL
# 499              NaN                        NaN          MX  TL
#
#     CLAVE_OTORGANTE NOMBRE DEL OTORGANTE  CREDITO_ACTUAL TIPO_RESPONSABILIDAD  \
# 158     MI999911111     HUATUSCO                 1003756                    I
# 466     MI999911111     HUATUSCO                 1003852                    I
# 499     MI999911111     HUATUSCO                 1003464                    I
#
#     TIPO_CTA TIPO_CONTRATO MONEDA  IMPORTE_AVALUO  NUM_PAGOS FRECUENCIA_PAGO  \
# 158        I            PL     MX             NaN         12               M
# 466        I            PL     MX             NaN          6               M
# 499        I            PL     MX             NaN         12               M
#
#      MONTO_A_PAGAR  FECHA_APERTURA  FECHA_ULTIMO_PAGO  \
# 158           2703        30012023           26052023
# 466           1119        14032023            5052023
# 499            962        30082022           25042023
#
#      FECHA_ULTIMA_DISPOSICION  FECHA_CIERRE  FECHA_REPORTE  GARANTIA  \
# 158                  30012023           NaN       31052023       NaN
# 466                  14032023           NaN       31052023       NaN
# 499                  30082022           NaN       31052023       NaN
#
#      MONTO_MAX_AUT  SALDO_ACTUAL  LIMITE_DE_CREDITO  SALDO_VENCIDO  \
# 158          31000         20691                  0              0
# 466           6000          4061                  0              0
# 499          10000          3207                  0            581
#
#      PAGOS_VENCIDOS  FORMA_PAGO CLAVE_OBSERVACION  CLAVE_USR_ANT  \
# 158               0           1               NaN            NaN
# 466               0           1               NaN            NaN
# 499               1           1               NaN            NaN
#
#      NOMBRE_USR_ANT  NOMBRE_CTA_ANT  FECHA_1ER_INCUMP  SALDO_INSOLUTO  \
# 158             NaN             NaN           1011900           20572
# 466             NaN             NaN           1011900            3942
# 499             NaN             NaN          31102022            3079
#
#      MONTO_ULTIMO_PAGO  F_INGRESO_CART_VENC  MONTO_INTERESES  \
# 158               3425              1011900              120
# 466               1181              1011900              119
# 499                985              1011900              129
#
#      FORMA_PAGO_INTERESES  DIAS_VENCIDOS  PLAZO_MESES  MONTO_ORIGINACION  \
# 158                     1              0        11.84              31000
# 466                     1              0         5.92               6000
# 499                     1              2        11.84              10000
#
#                                                  EMAIL  IDENTIFICADOR_CAN  \
# 158                                                ...                NaN
# 466                                                ...                NaN
# 499                                                ...                NaN
#
#      FECHA_APERTURA_CAN  FECHA_CANCELACION_CAN FIN_SEGMENTO
# 158                 NaN                    NaN          **|
# 466                 NaN                    NaN          **|
# 499                 NaN                    NaN          **|

# %%
buro_cp = df2[['CLAVE_ESTADO','DELEGACIÓN_O_MUNICIPIO', 'CODIGO_POSTAL']]
buro_cp.sample(3)
# Out:
#     CLAVE_ESTADO DELEGACIÓN_O_MUNICIPIO  CODIGO_POSTAL
# 58           VER               HUATUSCO          94107
# 295          VER               HUATUSCO          94100
# 476          VER                TOTUTLA          94059

# %%
query="""
SELECT * FROM buro_cp b  LEFT JOIN cp_veracruz v on (b.CODIGO_POSTAL=v.d_codigo)  
"""
datos=sqldf(query)
datos.sample(30)
# Out:
#      CLAVE_ESTADO DELEGACIÓN_O_MUNICIPIO  CODIGO_POSTAL  d_codigo  \
# 4             VER                TOTUTLA          94050   94050.0
# 1668          VER               HUATUSCO          94100   94100.0
# 1659          VER               HUATUSCO          94116   94116.0
# 3237          VER                TOTUTLA          94050   94050.0
# 2215          VER         PASO DEL MACHO          94970   94970.0
# 3809          VER                 ZENTLA          94220   94220.0
# 2536          VER                TOTUTLA          94050   94050.0
# 3582          VER                 ZENTLA          94220   94220.0
# 2307          VER                TOTUTLA          94050   94050.0
# 1870          VER     IXHUATLAN DEL CAFE          94180   94180.0
# 3765          VER                 ZENTLA          94220   94220.0
# 1582          VER               HUATUSCO          94100   94100.0
# 1622          VER               HUATUSCO          94100   94100.0
# 1400          VER           COSCOMATEPEC          94140   94140.0
# 2944          VER                TOTUTLA          94054   94054.0
# 2315          VER                TOTUTLA          94050   94050.0
# 2049          VER     IXHUATLAN DEL CAFE          94180   94180.0
# 1370          VER           COSCOMATEPEC          94140   94140.0
# 2238          VER             TEHUIPANGO          94050   94050.0
# 707           VER                 ZENTLA          94220   94220.0
# 894           VER                 COMAPA          94210   94210.0
# 2229          VER               SOCHIAPA          64060       NaN
# 2452          VER                TOTUTLA          94050   94050.0
# 2656          VER                TOTUTLA          94059   94059.0
# 1438          VER           COSCOMATEPEC          94140   94140.0
# 2021          VER     IXHUATLAN DEL CAFE          94180   94180.0
# 379           VER               HUATUSCO          94100   94100.0
# 2644          VER                TOTUTLA          94059   94059.0
# 3721          VER                 ZENTLA          94220   94220.0
# 1883          VER     IXHUATLAN DEL CAFE          94180   94180.0
#
#                            d_asenta                d_ciudad
# 4                        Palmaritos                    None
# 1668  Huatusco de Chicuellar Centro  HUATUSCO DE CHICUELLAR
# 1659                       Naranjos                    None
# 3237                  Los Barbechos                    None
# 2215                       San José          PASO DEL MACHO
# 3809                     El Pochote                    None
# 2536                      Tecomatla                    None
# 3582                Manuel Gonzalez                    None
# 2307                  Los Barbechos                    None
# 1870                20 de Noviembre                    None
# 3765                Manuel Gonzalez                    None
# 1582  Huatusco de Chicuellar Centro  HUATUSCO DE CHICUELLAR
# 1622             Unidad Antorchista  HUATUSCO DE CHICUELLAR
# 1400                     Tenixtepec                    None
# 2944                       Progreso                    None
# 2315                    El Capricho                    None
# 2049                      San Pedro                    None
# 1370                Lázaro Cárdenas                    None
# 2238                      Zapotitla                    None
# 707                       Maromilla                    None
# 894            El Jobo (Jobo Nuevo)                    None
# 2229                           None                    None
# 2452                  Los Barbechos                    None
# 2656                  Mata de Indio                    None
# 1438                     Los Álamos                    None
# 2021                       Presidio                    None
# 379                           SDTEV  HUATUSCO DE CHICUELLAR
# 2644                  Mata de Indio                    None
# 3721                      Maromilla                    None
# 1883                20 de Noviembre                    None
