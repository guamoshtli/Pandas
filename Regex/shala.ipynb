# %%
import pandas as pd
import re

# %%
df=pd.read_csv('internshala_dataset_raw.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2567 entries, 0 to 2566
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   internship                     2567 non-null   object
#  1   company_name                   2567 non-null   object
#  2   skills                         2220 non-null   object
#  3   perks                          1712 non-null   object
#  4   location                       2567 non-null   object
#  5   duration                       2567 non-null   object
#  6   stipend                        2567 non-null   object
#  7   applicants                     2567 non-null   object
#  8   ifSkillsorPerksMissingUseThis  2535 non-null   object
# dtypes: object(9)
# memory usage: 180.6+ KB

# %% [markdown]
# Step 1: Create Sample DataFrame

# %%
df.sample(2)
# Out:
#                internship                      company_name  \
# 2535  Node.js Development                           Monkhub
# 276       Web Development  Dignity Software Private Limited
#
#                                                  skills  \
# 2535  JavaScript, Node.js, GitHub, Firebase, Firebas...
# 276   PHP, HTML, CSS, JavaScript, Adobe Photoshop, W...
#
#                                                  perks        location  \
# 2535                                               NaN  Work From Home
# 276   Certificate, Letter of recommendation, Job offer           Delhi
#
#       duration            stipend             applicants  \
# 2535  2 Months  8000-12000 /month         191 applicants
# 276   6 Months        2000 /month  Be an early applicant
#
#                           ifSkillsorPerksMissingUseThis
# 2535  JavaScript\nNode.js\nGitHub\nFirebase\nFirebas...
# 276   PHP\nHTML\nCSS\nJavaScript\nAdobe Photoshop\nW...

# %% [markdown]
# Step 2: Replace String Values with Regex in Column
#
# Let's start with replacing string values in column applicants. As you can see the values in the column are mixed.
#
# There are two options:

# %%
df['applicants'].unique()
# Out:
# array(['119 applicants', '194 applicants', '113 applicants',
#        '183 applicants', '205 applicants', '457 applicants',
#        '54 applicants', '618 applicants', 'Be an early applicant',
#        '34 applicants', '28 applicants', '32 applicants', '41 applicants',
#        '35 applicants', '31 applicants', '46 applicants', '49 applicants',
#        '57 applicants', '38 applicants', '43 applicants', '44 applicants',
#        '75 applicants', '39 applicants', '37 applicants', '48 applicants',
#        '47 applicants', '55 applicants', '66 applicants', '27 applicants',
#        '26 applicants', '52 applicants', '62 applicants', '68 applicants',
#        '72 applicants', '50 applicants', '78 applicants', '70 applicants',
#        '84 applicants', '120 applicants', '139 applicants',
#        '33 applicants', '45 applicants', '263 applicants',
#        '59 applicants', '95 applicants', '36 applicants', '64 applicants',
#        '89 applicants', '86 applicants', '76 applicants', '63 applicants',
#        '107 applicants', '143 applicants', '80 applicants',
#        '42 applicants', '58 applicants', '127 applicants',
#        '110 applicants', '309 applicants', '91 applicants',
#        '30 applicants', '82 applicants', '93 applicants', '85 applicants',
#        '129 applicants', '117 applicants', '29 applicants',
#        '60 applicants', '40 applicants', '61 applicants', '51 applicants',
#        '122 applicants', '192 applicants', '230 applicants',
#        '102 applicants', '100 applicants', '88 applicants',
#        '268 applicants', '115 applicants', '265 applicants',
#        '56 applicants', '87 applicants', '65 applicants',
#        '238 applicants', '144 applicants', '69 applicants',
#        '299 applicants', '121 applicants', '233 applicants',
#        '125 applicants', '79 applicants', '174 applicants',
#        '155 applicants', '73 applicants', '104 applicants',
#        '135 applicants', '156 applicants', '167 applicants',
#        '131 applicants', '164 applicants', '94 applicants',
#        '81 applicants', '53 applicants', '71 applicants',
#        '106 applicants', '142 applicants', '83 applicants',
#        '178 applicants', '74 applicants', '114 applicants',
#        '96 applicants', '90 applicants', '172 applicants',
#        '123 applicants', '103 applicants', '405 applicants',
#        '99 applicants', '108 applicants', '150 applicants',
#        '185 applicants', '145 applicants', '202 applicants',
#        '184 applicants', '128 applicants', '130 applicants',
#        '147 applicants', '77 applicants', '260 applicants',
#        '134 applicants', '67 applicants', '351 applicants',
#        '136 applicants', '379 applicants', '179 applicants',
#        '92 applicants', '204 applicants', '242 applicants',
#        '151 applicants', '133 applicants', '305 applicants',
#        '124 applicants', '346 applicants', '118 applicants',
#        '140 applicants', '229 applicants', '186 applicants',
#        '97 applicants', '391 applicants', '170 applicants',
#        '126 applicants', '256 applicants', '173 applicants',
#        '138 applicants', '240 applicants', '161 applicants',
#        '317 applicants', '191 applicants', '111 applicants',
#        '279 applicants', '157 applicants', '112 applicants',
#        '364 applicants', '197 applicants', '645 applicants',
#        '482 applicants', '163 applicants', '153 applicants',
#        '219 applicants', '211 applicants', '322 applicants',
#        '171 applicants', '212 applicants', '324 applicants',
#        '190 applicants', '98 applicants', '105 applicants',
#        '277 applicants', '275 applicants', '187 applicants',
#        '398 applicants', '222 applicants', '257 applicants',
#        '214 applicants', '206 applicants', '199 applicants',
#        '182 applicants', '116 applicants', '271 applicants',
#        '331 applicants', '310 applicants', '154 applicants',
#        '169 applicants', '101 applicants', '334 applicants',
#        '296 applicants', '292 applicants', '283 applicants',
#        '162 applicants', '288 applicants', '245 applicants',
#        '177 applicants', '160 applicants', '323 applicants',
#        '298 applicants', '254 applicants', '166 applicants',
#        '501 applicants', '252 applicants', '208 applicants',
#        '502 applicants', '223 applicants', '225 applicants',
#        '241 applicants', '215 applicants', '420 applicants',
#        '341 applicants', '236 applicants', '137 applicants',
#        '352 applicants', '209 applicants', '259 applicants',
#        '181 applicants', '377 applicants', '231 applicants',
#        '149 applicants', '1000+ applicants', '247 applicants',
#        '220 applicants', '290 applicants', '132 applicants',
#        '286 applicants', '246 applicants', '855 applicants',
#        '450 applicants', '399 applicants', '598 applicants',
#        '266 applicants', '306 applicants', '203 applicants'], dtype=object)

# %%
df['applicants']= df['applicants'].str.replace(r'\sapplicants', '', regex=True)
df['applicants'].unique()
# Out:
# array(['119', '194', '113', '183', '205', '457', '54', '618',
#        'Be an early applicant', '34', '28', '32', '41', '35', '31', '46',
#        '49', '57', '38', '43', '44', '75', '39', '37', '48', '47', '55',
#        '66', '27', '26', '52', '62', '68', '72', '50', '78', '70', '84',
#        '120', '139', '33', '45', '263', '59', '95', '36', '64', '89',
#        '86', '76', '63', '107', '143', '80', '42', '58', '127', '110',
#        '309', '91', '30', '82', '93', '85', '129', '117', '29', '60',
#        '40', '61', '51', '122', '192', '230', '102', '100', '88', '268',
#        '115', '265', '56', '87', '65', '238', '144', '69', '299', '121',
#        '233', '125', '79', '174', '155', '73', '104', '135', '156', '167',
#        '131', '164', '94', '81', '53', '71', '106', '142', '83', '178',
#        '74', '114', '96', '90', '172', '123', '103', '405', '99', '108',
#        '150', '185', '145', '202', '184', '128', '130', '147', '77',
#        '260', '134', '67', '351', '136', '379', '179', '92', '204', '242',
#        '151', '133', '305', '124', '346', '118', '140', '229', '186',
#        '97', '391', '170', '126', '256', '173', '138', '240', '161',
#        '317', '191', '111', '279', '157', '112', '364', '197', '645',
#        '482', '163', '153', '219', '211', '322', '171', '212', '324',
#        '190', '98', '105', '277', '275', '187', '398', '222', '257',
#        '214', '206', '199', '182', '116', '271', '331', '310', '154',
#        '169', '101', '334', '296', '292', '283', '162', '288', '245',
#        '177', '160', '323', '298', '254', '166', '501', '252', '208',
#        '502', '223', '225', '241', '215', '420', '341', '236', '137',
#        '352', '209', '259', '181', '377', '231', '149', '1000+', '247',
#        '220', '290', '132', '286', '246', '855', '450', '399', '598',
#        '266', '306', '203'], dtype=object)

# %%
df['applicants_clean']=df['applicants'].str.replace(r'(\sapplicants|Be an early applicant)', '', regex=True)
df['applicants_clean'].unique()
# Out:
# array(['119', '194', '113', '183', '205', '457', '54', '618', '', '34',
#        '28', '32', '41', '35', '31', '46', '49', '57', '38', '43', '44',
#        '75', '39', '37', '48', '47', '55', '66', '27', '26', '52', '62',
#        '68', '72', '50', '78', '70', '84', '120', '139', '33', '45',
#        '263', '59', '95', '36', '64', '89', '86', '76', '63', '107',
#        '143', '80', '42', '58', '127', '110', '309', '91', '30', '82',
#        '93', '85', '129', '117', '29', '60', '40', '61', '51', '122',
#        '192', '230', '102', '100', '88', '268', '115', '265', '56', '87',
#        '65', '238', '144', '69', '299', '121', '233', '125', '79', '174',
#        '155', '73', '104', '135', '156', '167', '131', '164', '94', '81',
#        '53', '71', '106', '142', '83', '178', '74', '114', '96', '90',
#        '172', '123', '103', '405', '99', '108', '150', '185', '145',
#        '202', '184', '128', '130', '147', '77', '260', '134', '67', '351',
#        '136', '379', '179', '92', '204', '242', '151', '133', '305',
#        '124', '346', '118', '140', '229', '186', '97', '391', '170',
#        '126', '256', '173', '138', '240', '161', '317', '191', '111',
#        '279', '157', '112', '364', '197', '645', '482', '163', '153',
#        '219', '211', '322', '171', '212', '324', '190', '98', '105',
#        '277', '275', '187', '398', '222', '257', '214', '206', '199',
#        '182', '116', '271', '331', '310', '154', '169', '101', '334',
#        '296', '292', '283', '162', '288', '245', '177', '160', '323',
#        '298', '254', '166', '501', '252', '208', '502', '223', '225',
#        '241', '215', '420', '341', '236', '137', '352', '209', '259',
#        '181', '377', '231', '149', '1000+', '247', '220', '290', '132',
#        '286', '246', '855', '450', '399', '598', '266', '306', '203'],
#       dtype=object)

# %% [markdown]
# Step 3: Regex replace with capture group
#
# In this step we will take a deeper look on regex and capture groups in Pandas.
#
# They are powerful tool to match a pattern and extract only part of it.
#
# Let's say that we would like to match : 63 applicants but only extract the numbers. In other words, to search for a numeric sequence followed by anything.
#
# We are capturing two groups but will keep only the first one - the numbers.

# %%
df['applicants'].unique()
# Out:
# array(['119', '194', '113', '183', '205', '457', '54', '618',
#        'Be an early applicant', '34', '28', '32', '41', '35', '31', '46',
#        '49', '57', '38', '43', '44', '75', '39', '37', '48', '47', '55',
#        '66', '27', '26', '52', '62', '68', '72', '50', '78', '70', '84',
#        '120', '139', '33', '45', '263', '59', '95', '36', '64', '89',
#        '86', '76', '63', '107', '143', '80', '42', '58', '127', '110',
#        '309', '91', '30', '82', '93', '85', '129', '117', '29', '60',
#        '40', '61', '51', '122', '192', '230', '102', '100', '88', '268',
#        '115', '265', '56', '87', '65', '238', '144', '69', '299', '121',
#        '233', '125', '79', '174', '155', '73', '104', '135', '156', '167',
#        '131', '164', '94', '81', '53', '71', '106', '142', '83', '178',
#        '74', '114', '96', '90', '172', '123', '103', '405', '99', '108',
#        '150', '185', '145', '202', '184', '128', '130', '147', '77',
#        '260', '134', '67', '351', '136', '379', '179', '92', '204', '242',
#        '151', '133', '305', '124', '346', '118', '140', '229', '186',
#        '97', '391', '170', '126', '256', '173', '138', '240', '161',
#        '317', '191', '111', '279', '157', '112', '364', '197', '645',
#        '482', '163', '153', '219', '211', '322', '171', '212', '324',
#        '190', '98', '105', '277', '275', '187', '398', '222', '257',
#        '214', '206', '199', '182', '116', '271', '331', '310', '154',
#        '169', '101', '334', '296', '292', '283', '162', '288', '245',
#        '177', '160', '323', '298', '254', '166', '501', '252', '208',
#        '502', '223', '225', '241', '215', '420', '341', '236', '137',
#        '352', '209', '259', '181', '377', '231', '149', '1000+', '247',
#        '220', '290', '132', '286', '246', '855', '450', '399', '598',
#        '266', '306', '203'], dtype=object)

# %%
df['applicants_3']=df['applicants'].replace(to_replace=r"([0-9,\.]+)(.*)", value=r"\1", regex=True)
df['applicants_3'].unique()
# Out:
# array(['119', '194', '113', '183', '205', '457', '54', '618',
#        'Be an early applicant', '34', '28', '32', '41', '35', '31', '46',
#        '49', '57', '38', '43', '44', '75', '39', '37', '48', '47', '55',
#        '66', '27', '26', '52', '62', '68', '72', '50', '78', '70', '84',
#        '120', '139', '33', '45', '263', '59', '95', '36', '64', '89',
#        '86', '76', '63', '107', '143', '80', '42', '58', '127', '110',
#        '309', '91', '30', '82', '93', '85', '129', '117', '29', '60',
#        '40', '61', '51', '122', '192', '230', '102', '100', '88', '268',
#        '115', '265', '56', '87', '65', '238', '144', '69', '299', '121',
#        '233', '125', '79', '174', '155', '73', '104', '135', '156', '167',
#        '131', '164', '94', '81', '53', '71', '106', '142', '83', '178',
#        '74', '114', '96', '90', '172', '123', '103', '405', '99', '108',
#        '150', '185', '145', '202', '184', '128', '130', '147', '77',
#        '260', '134', '67', '351', '136', '379', '179', '92', '204', '242',
#        '151', '133', '305', '124', '346', '118', '140', '229', '186',
#        '97', '391', '170', '126', '256', '173', '138', '240', '161',
#        '317', '191', '111', '279', '157', '112', '364', '197', '645',
#        '482', '163', '153', '219', '211', '322', '171', '212', '324',
#        '190', '98', '105', '277', '275', '187', '398', '222', '257',
#        '214', '206', '199', '182', '116', '271', '331', '310', '154',
#        '169', '101', '334', '296', '292', '283', '162', '288', '245',
#        '177', '160', '323', '298', '254', '166', '501', '252', '208',
#        '502', '223', '225', '241', '215', '420', '341', '236', '137',
#        '352', '209', '259', '181', '377', '231', '149', '1000', '247',
#        '220', '290', '132', '286', '246', '855', '450', '399', '598',
#        '266', '306', '203'], dtype=object)

# %% [markdown]
# Step 4: Regex replace only special characters
#
# What if we would like to clean or remove all special characters while keeping numbers and letters.
#
# In that case we can use one of the next regex:
#
# r'[^0-9a-zA-Z:,\s]+' - keep numbers, letters, semicolon, comma and space
# r'[^0-9a-zA-Z:,]+' - keep numbers, letters, semicolon and comma
# So the code looks like:

# %%
df['internship'].unique()
# Out:
# array(['Software Testing',
#        'Technical Operations - Networking And Monitoring',
#        'Software Project Management', 'Web Development',
#        'Front End Development', 'Web Design', 'Node.js Development',
#        'C++ Development (QT Creation)', 'Quality Control & Testing',
#        'Software Support Engineering', 'Full Stack Development (MERN)',
#        'Business Analysis',
#        'Server Side Software Engineering (Backend-GoLang)',
#        'International Technical Support', 'iOS App Development',
#        'Mobile App Development', 'AWS Engineering', 'React Development',
#        'Product Management', 'Flutter Development', 'Java Development',
#        'WordPress Development', 'WordPress Website Design',
#        'Cyber Security Audit', 'Android Development', 'Rust Development',
#        'Internet Of Things (IoT)',
#        'Front End Development (React/Angular)', '.Net Development',
#        'PHP Development', 'Full Stack Development', 'Backend Development',
#        'Quality Analysis', 'iOS Research (Video Playback)',
#        'Information Technology', 'Business Analytics',
#        'Software Testing (API/Postman)', 'Computer Operations',
#        'Cyber Security Operations',
#        'Online Coding Teaching (Scratch/MIT App Inventor/Code.org)',
#        'Data Science And Python', 'Programming', 'VAPT Analysis',
#        'Teaching (Artificial Intelligence)', 'GIS', 'ReactJS Development',
#        'React Native Development', 'Python Development',
#        'Teaching (Python & Robotics)', 'QA Manual Testing',
#        'iOS Development', 'Teaching (Coding)', 'ASP.Net MVC Development',
#        'Cyber Security Testing', 'Frontend Development (React Native)',
#        'React & Redux Development', 'Web & Mobile App Development',
#        'Java/Python/QA', 'Web Development (React.js & Node.js)',
#        'Website Fixes And Management (WordPress And HTML)',
#        'Software Development', 'Dart/Flutter App Development',
#        'Technical Support', 'Teaching (Augmented Reality Based Game)',
#        'PHP & Laravel Development', 'Game/Application Testing',
#        'Technical Engineering', 'JavaScript Development & Automation',
#        'Coding Instruction', 'Website Management', 'Django Development',
#        'Android App Development', 'Software Engineering (Chatbot)',
#        'DevOps (Azure CICD & Jenkins CICD)',
#        'Research Paper Writing (Artificial Intelligence & Robotics)',
#        'MATLAB Programming', 'Application Development',
#        'Backend Development (Golang)', 'Web Development (Backend)',
#        'Technical Project Management', '3D Character Modeling',
#        'Coaching (Agile)', 'Machine Learning (Python)', 'Cyber Security',
#        'Python/Django Development', 'Automated Software Testing',
#        'Web Development (ReactJS & Node.js)',
#        'Computer Vision & Machine Learning Engineering',
#        'Quality Testing - Website', 'Computer Vision',
#        'Embedded Systems Programming', 'Artificial Intelligence (AI)',
#        'Data Science', 'JavaScript Development (Node.js)',
#        'JavaScript Development', 'Network Engineering',
#        'Game (Unity3D) Development - Preferrable M.Tech Grads',
#        'DevOps/Cloud Engineering', 'Information Security Management',
#        'Blockchain Development', 'Python Full Stack Development',
#        'Web Development (Full Stack)', 'Scrum Management',
#        'Programming/Algorithm Development', 'Project Management',
#        'Data Management', 'Spring Boot Development (Java)',
#        'Springboot Development', 'Web Development (ReactJS)',
#        'Angular Development', 'Application Support Engineering',
#        'Mobile App Development (iOS & Android)', 'C++ Programming',
#        'Subject Matter Expert (Computer Science)',
#        'Web Development (Java Spring Framework)', 'React/React JS',
#        'React Native Developer', 'API Development & Integration',
#        'Subject Matter Expert - HTML', 'Software Testing (Manual)',
#        'Angular.js Development', 'PHP And WordPress Development',
#        'DevOps & Site Reliability Engineering', 'Flutter App Development',
#        'AR/VR Development', 'HubSpot Development',
#        'IT Project Management', 'Web Development (Django)',
#        'React Development (Front-End)', 'Android Engineering',
#        'Laravel Development', 'WordPress Design', 'Unity Development',
#        'React Native Development (Android/iOS)', 'PHP Web Develoment',
#        'MEAN Stack Development', 'Product Management (Technical)',
#        'Content Development (ICT/Computer Science)',
#        'QA/Software Testing', 'Backend Development (Node.js)',
#        'Web Designing', 'Project Coordination (MBA/PGDM Graduate)',
#        "Full Stack Development (Founder's Office)",
#        'MERN Stack Development', 'Teaching (Web Development)',
#        'Machine Learning & Artificial Intelligence',
#        'Project Management (Interactive Division)',
#        'NoSQL Database Development',
#        'Artificial Intelligence & Machine Learning Development',
#        'Electronics Instrumentation', 'Software Engineering (Automation)',
#        'Power BI Development', 'Android/Flutter Development',
#        'NodeJS Development', 'DevOps', 'Desktop Engineering',
#        'Full Stack Development (MEAN Stack)',
#        'Associate Software Development',
#        'Embedded Systems Firmware Development',
#        'Lecture Creation (Computer Science)', 'Online Teaching (Java)',
#        'Computer Science Engineering', 'Ruby On Rails Development',
#        'Unity 3D (Game Development)', 'Course Development (Blockchain)',
#        'Technical Software Implementation', 'SAP ABAP Programming',
#        'Wix Web Development', 'QT/QML Augmented Reality',
#        'Computer Vision Development', 'Technical Writing',
#        'Programming & CAD Design', 'Software Engineering',
#        'MERN Development', 'Front End Web Development',
#        'WordPress Web Development', 'React Native', 'Ethical Hacking',
#        'ReactJS Web Development', 'Full Stack Engineering (ReactJS)',
#        'Selenium Test Automation', 'Camera DSP Management',
#        'Web Development (Wix)', 'Manual Software Testing',
#        'Mobile App Development (Node.js)',
#        'Mobile App Development (React.js)',
#        'Full Stack Development (Java/.NET/Python)',
#        'Software Development (GoLang)', 'Front End Engineering',
#        'Game Development', 'Research & Development (Proof of Concept)',
#        'System Design (IoT & Robotics)',
#        'Artificial Intelligence/Machine Learning (IoT & Robotics)',
#        'Software Testing/Quality Assurance', 'Firmware Development',
#        'Skill Based Gaming', 'Back End Application Development (Python)',
#        'Mobile Engineering (Android)', 'Teaching',
#        'Subject Matter Expert (Computer Science/IT)',
#        'Full Stack Development (JS/MEAN Stack)',
#        'Flutter/Dart Development',
#        'Backend Development (Algo Trading Strategy Coding)',
#        'Robotics/STEM (Teaching)', 'KPI Dashboard Development',
#        'Django Backend Development',
#        'Machine Learning And Python Development',
#        'Website SEO & Optimization', 'Research (AI/ML)',
#        'JavaScript Extension', 'Technical Program Management (Executive)',
#        'Frontend Development (ReactJs)', 'Technical Program Management',
#        'Python & AWS Development', 'Chatbot Development',
#        'Computer Science', 'Bootstrap Development',
#        'Embedded Linux Distro Development - Yocto',
#        'Laravel Web Development', 'Full Stack Development (Golang)',
#        'C# Programming', 'Front End Web Development (Shopify)',
#        'Full Stack Development (Frontend Heavy)',
#        'WordPress Design/Development', 'Teach Coding (Arabic)',
#        'Full Stack Development (MEAN Stack) Angular',
#        'Software Development (Java Spring Boot)', 'Ionic App Development',
#        'DevOps Management', 'Web Development (Front End)',
#        'Mobile App Development (Flutter)', 'Microsoft Azure',
#        'Teaching (Frontend Web Development)',
#        'Python & React.js Development',
#        'Android App Development/Kotlin Programming (Smart App Development)',
#        'iOS App Development (Swift)', 'AWS Cloud Management',
#        'Artificial Neural Networks', 'Backend Development (MERN Stack)',
#        'Backend (Nodejs) Development',
#        'Software Testing (QA Engineering)', 'Angular Programming',
#        'Web Development (WordPress)', 'Arduino Development',
#        'ASP.NET Development', 'Quality Assurance', 'DevOps (AWS)',
#        'Backend Development (Node.js & PHP)', 'Knowledge Evangelist',
#        'UI Development', 'Data Extraction',
#        'PHP Development (CodeIgniter)', 'International Teaching (Coding)',
#        'Android App Testing', 'C#', 'AI Engineering',
#        'System Design Engineering',
#        'HTML & CSS Development (UI & UX Design)',
#        'Power Business Intelligence (Power BI Development)',
#        'Ethereum Blockchain Smart Contract (Solidity) Development',
#        'DevOps Engineering', 'Django Rest Framework Development',
#        'DRF Development', 'React.js Development',
#        'Angular.js/JavaScript/Node.js Development', 'UI/UX Design',
#        'Digital Image Processing',
#        'Deep Learning & Computer Vision Engineering (Autonomous Vehicles)',
#        'DevOps Internship', 'Coding', '3D Development',
#        'Project Management (Scrum)', 'Database/Oracle Development',
#        'PCB Design Assembly & Testing', 'PHP Development (Laravel)',
#        'Artificial Intelligence & Machine Learning',
#        'Elementor Development',
#        'UAV Code Development (ROS/ROS2/C++/Python)',
#        'Unity Game Development', 'Backend Management',
#        'CS/ECE/IT Engineering', '3D Modeling', 'Python/Django',
#        'Project Coordination', 'AngularJS Development', 'Robotics',
#        'Software Development Engineering', '.NET & C# development',
#        'ReactJS Front End Development', 'Front-end Development (Angular)',
#        'Python NodeJS Development', 'Frontend Development (UI/UX)',
#        'Network Administration (CCNA & IoT Network)',
#        'Product Engineering (Frontend Engineering)',
#        'Web App Development (Python/Django)',
#        'iOS App Development (Flutter)', 'Information Security Consulting',
#        'Operating Systems Internals (Core OS)',
#        'Flutter Mobile App Development',
#        'System Programming (Operating System Adminstration)',
#        'Cyber Security Analytics', 'Computer Vision System Development',
#        'Web Development (Laravel Framework)', 'Teaching (Technical)',
#        'Postgres Database Administration',
#        'Teaching/Mentoring (Online Coding)', 'Unity App Development',
#        'Online Teaching', 'Software Development Engineering (Web)',
#        'Product Engineering (Backend)', 'Backend Engineering',
#        'Manage Services (Azure)', 'Python Development And Django',
#        'Django/WordPress Development', 'API Development',
#        'Electronics Training (Coding & Robotics)', 'Google App Scripts',
#        'V2V Communication Spectrum Analysis - MATLAB',
#        'Android App Development - Flutter',
#        'Backend Development (Ruby on Rails)',
#        'Raspberry Pi Application Development', 'Embedded Software',
#        'Deep Learning/Computer Vision', 'Cloud Security Engineering',
#        'Laravel', 'Web Scraping', 'UI Development (ReactJS)',
#        'Machine Learning', 'AngularJS/Advanced JavaScript Development',
#        'Graphic Design (Game)', 'Tutoring (Coding)',
#        '.NET/MS BI Development', 'Embedded Engineering',
#        'DevOps Development', 'Game Testing',
#        'Subject Matter Expert (CSE/MCA/IT)',
#        'Django And GraphQL Development',
#        'Embedded Hardware And Software Engineering',
#        'Cyber Security Development', 'Cybersecurity - Pen Testing',
#        'Backend SDE Development', 'iOS (Swift 5) App Development',
#        'Shopify Development', 'Data Analytics',
#        'Software Development (IoT)', 'Embedded Programming',
#        'Functional Product Consulting', 'Android & IOS Testing',
#        'Python & JavaScript Development',
#        'Technical Administration Assistance',
#        'Web Game Development (JS And Matter.js)', 'Teaching (Python)',
#        'ReactJS Development (API Integration)', 'Magento Development',
#        'Back-End Development (Node.js)',
#        'Google Sheet Query Writing & Dashboard Creation',
#        'Cloud Computing', 'React JS PWA Development',
#        'Full Stack Development (Python - Backend)',
#        'Unreal Engine Game Development', 'Node.js & WebRTC Development',
#        'Back-end Development (Functional Programming)',
#        'Video Solutions (Physics/Computer Science/Mechanical)',
#        'Angular App Development', 'WordPress & PHP Development',
#        'Backend Development (Django)', 'REST API Development',
#        'ROS Development', 'Technical Content Writing',
#        'Front End/Backend Development', 'App Development (Flutter)',
#        'Python (Market Research)', 'Process Simulation Management',
#        'Augmented Reality Development', 'Python (Mathematics)',
#        'Python (Finance)', 'Embedded Software Development',
#        'Full Stack Development (Python)', 'Salesforce Development',
#        'Python Visualization', 'Vuejs Development',
#        'Scripting Development', 'Advanced PHP Development',
#        'Mobile App Development (React Native)', 'Hardware Field Testing',
#        'Full Stack Development (Django/ReactJS)',
#        'Linux System Administration',
#        'Hardware Engineering (Prototyping/Testing)', 'UI/UX Testing',
#        'Pre-Sales (IT)', 'Python Development (Django)',
#        'Firmware Engineering (C/C++)',
#        'Product Development And Implementation',
#        'ReactJS/React Native Development', 'Mobile/Web App Development',
#        'Application Testing',
#        'Technical Support Associate (Network Firewall)',
#        'Front End Development - Angular', 'C# Windows Forms Development',
#        'SQL Development', 'Content Creation (Linux)', 'ReactJS',
#        'Product Management (Ed-tech/Talent Acquisition)',
#        'Desktop Application Development', 'Teaching Assistance (Java)',
#        'IT Service', 'Wireless Driver Research',
#        'Teaching (Online Robotics)',
#        'Product Development - Prototype Engineering',
#        'Technical Operations',
#        'Video Content Development (Web Development)',
#        'Video Content Development (Java Course)',
#        'Video Online Course Development (Python)',
#        'Video Content Development (Android App Development)',
#        'Signal Processing - Wavelets',
#        'Video Content Development (C++ Programming)',
#        'ReactJS & NodeJS Development (Mern Stack Development)',
#        'Product Management (Mobile Apps)',
#        'Video Content Development (Artificial Intelligence)',
#        'Video Content Development (Machine Learning)',
#        'Networking & Administration',
#        'Teaching (Android App Development)', 'Teaching (Ethical Hacking)',
#        'Azure Development',
#        'Python Development (Data Automation & Core Scripting)',
#        'Flutter Development For PWA (Progressive Web App)',
#        'Battery Pack And Software Development',
#        'Full Stack Development (Angular/Firebase)',
#        'Content Creation (Python)', 'Data Structure Development',
#        'ReactJS Development (.NET Environment)',
#        'Angular 7 & Node.js Development With MongoDB/Firebase',
#        'Python Automation And Scrapping',
#        'Data Science & Machine Learning',
#        'Whitepaper Management (Computer Science)',
#        'React Native Mobile App Development', 'QA & Project Coordination',
#        'Deep Learning AI Software Development', 'Teaching (Computer)',
#        'Content Management',
#        'Summer Research Intern - Artificial Intelligence',
#        'Online Teaching (Coding)', 'VUE.js Development',
#        'Computer Science (IT)', 'Web Development (React)',
#        'Cloud & Network (Specialist)', 'User Research (App)',
#        'Software Engineering (.NET/DevOps)',
#        'Backend/Full Stack Development',
#        'Code Development (ROS/ROS 2/C++)', 'Web Development (Teaching)',
#        'Quality Assurance & Testing', 'Power Automate RPA',
#        'Content Writing (Game Development)', 'Coding Teaching',
#        'Back End Development/Full Stack Development', 'Manual Testing',
#        'Teaching (Python & Mathematics)', 'QA Engineering',
#        'Flutter Mobile Development', 'Programming C++',
#        'Quality Assurance (QA)', 'Game Art (3D & 2D)',
#        'Training (MIT App Development/Android)',
#        'Training (Cyber Security)', 'Training (Robotics)',
#        'Kotlin Development', 'Front-end Development', 'Swift Development',
#        'Embedded Systems', 'Web Development (WordPress And WooCommerce)',
#        'Computer Vision & Deep Learning',
#        'Quality Analysis (Software Development)',
#        'Incident Response/Threat Intelligence/Malware Analysis/SOC L1',
#        'MySQL Development', 'Robotics Engineering (AI/Computer Vision)',
#        'Course Development (Java Programming)',
#        'Research (Python Development)',
#        'Technical Teaching (Artificial Intelligence)', 'ABAP Programming',
#        'Subject Matter Expert (JavaScript)', 'System Engineering (IT)',
#        'Information & Communication Technologies (ICT)',
#        'Natural Language Processing Development', 'MLOps',
#        'Teaching (IT)', 'Embedded Systems Engineering',
#        'Embedded Software (Raspberry Pi & AI)',
#        'Teaching (Computer Applications)',
#        'Teaching (Software Development)', 'PHP Laravel Development',
#        'ReactJS Development (Front-end)', 'IT Operations',
#        'Microsoft Power BI', 'GUI Development', 'Software Programming',
#        'Software Packaging', 'Angular Web Development',
#        'Systems Engineering',
#        'Full Stack Teaching (PHP/JS HTML/CSS/JQUERY)',
#        'Unity3D Application Development',
#        'Python/Django/Postgress SQL Development', 'Heroku Development',
#        'Cloud Engineering (Projects)',
#        'Flutter Mobile Application Development',
#        'Huawei Cloud Software Deployment Configuration',
#        'Mobile App Testing', 'Software Tech Support',
#        'Unreal Development', 'Website Testing & Content Audit',
#        'Advanced Web Automation', 'Wix/Wordpress Development',
#        'Advanced Web Development', 'Mobile Game Development',
#        'Teaching (Python Programming)', 'Research & Training (Robotics)',
#        'Embedded Systems Development',
#        'Project & Product Management (Blockchain)',
#        'Web Development (Wix.com)',
#        'Front End Development (Angular/UI/UX)', 'Support Engineering',
#        'C++ Development', 'IT & Web Development',
#        'System Administration/DevOps', 'Node.js & ReactJS Development',
#        'Summer Research', 'Academic Research (Computer Science)'],
#       dtype=object)

# %%
df4= df['internship'].str.replace(r'[^0-9a-zA-Z:,\s]+', '', regex=True)

# %%
df4.unique()
# Out:
# array(['Software Testing',
#        'Technical Operations  Networking And Monitoring',
#        'Software Project Management', 'Web Development',
#        'Front End Development', 'Web Design', 'Nodejs Development',
#        'C Development QT Creation', 'Quality Control  Testing',
#        'Software Support Engineering', 'Full Stack Development MERN',
#        'Business Analysis',
#        'Server Side Software Engineering BackendGoLang',
#        'International Technical Support', 'iOS App Development',
#        'Mobile App Development', 'AWS Engineering', 'React Development',
#        'Product Management', 'Flutter Development', 'Java Development',
#        'WordPress Development', 'WordPress Website Design',
#        'Cyber Security Audit', 'Android Development', 'Rust Development',
#        'Internet Of Things IoT', 'Front End Development ReactAngular',
#        'Net Development', 'PHP Development', 'Full Stack Development',
#        'Backend Development', 'Quality Analysis',
#        'iOS Research Video Playback', 'Information Technology',
#        'Business Analytics', 'Software Testing APIPostman',
#        'Computer Operations', 'Cyber Security Operations',
#        'Online Coding Teaching ScratchMIT App InventorCodeorg',
#        'Data Science And Python', 'Programming', 'VAPT Analysis',
#        'Teaching Artificial Intelligence', 'GIS', 'ReactJS Development',
#        'React Native Development', 'Python Development',
#        'Teaching Python  Robotics', 'QA Manual Testing',
#        'iOS Development', 'Teaching Coding', 'ASPNet MVC Development',
#        'Cyber Security Testing', 'Frontend Development React Native',
#        'React  Redux Development', 'Web  Mobile App Development',
#        'JavaPythonQA', 'Web Development Reactjs  Nodejs',
#        'Website Fixes And Management WordPress And HTML',
#        'Software Development', 'DartFlutter App Development',
#        'Technical Support', 'Teaching Augmented Reality Based Game',
#        'PHP  Laravel Development', 'GameApplication Testing',
#        'Technical Engineering', 'JavaScript Development  Automation',
#        'Coding Instruction', 'Website Management', 'Django Development',
#        'Android App Development', 'Software Engineering Chatbot',
#        'DevOps Azure CICD  Jenkins CICD',
#        'Research Paper Writing Artificial Intelligence  Robotics',
#        'MATLAB Programming', 'Application Development',
#        'Backend Development Golang', 'Web Development Backend',
#        'Technical Project Management', '3D Character Modeling',
#        'Coaching Agile', 'Machine Learning Python', 'Cyber Security',
#        'PythonDjango Development', 'Automated Software Testing',
#        'Web Development ReactJS  Nodejs',
#        'Computer Vision  Machine Learning Engineering',
#        'Quality Testing  Website', 'Computer Vision',
#        'Embedded Systems Programming', 'Artificial Intelligence AI',
#        'Data Science', 'JavaScript Development Nodejs',
#        'JavaScript Development', 'Network Engineering',
#        'Game Unity3D Development  Preferrable MTech Grads',
#        'DevOpsCloud Engineering', 'Information Security Management',
#        'Blockchain Development', 'Python Full Stack Development',
#        'Web Development Full Stack', 'Scrum Management',
#        'ProgrammingAlgorithm Development', 'Project Management',
#        'Data Management', 'Spring Boot Development Java',
#        'Springboot Development', 'Web Development ReactJS',
#        'Angular Development', 'Application Support Engineering',
#        'Mobile App Development iOS  Android', 'C Programming',
#        'Subject Matter Expert Computer Science',
#        'Web Development Java Spring Framework', 'ReactReact JS',
#        'React Native Developer', 'API Development  Integration',
#        'Subject Matter Expert  HTML', 'Software Testing Manual',
#        'Angularjs Development', 'PHP And WordPress Development',
#        'DevOps  Site Reliability Engineering', 'Flutter App Development',
#        'ARVR Development', 'HubSpot Development', 'IT Project Management',
#        'Web Development Django', 'React Development FrontEnd',
#        'Android Engineering', 'Laravel Development', 'WordPress Design',
#        'Unity Development', 'React Native Development AndroidiOS',
#        'PHP Web Develoment', 'MEAN Stack Development',
#        'Product Management Technical',
#        'Content Development ICTComputer Science', 'QASoftware Testing',
#        'Backend Development Nodejs', 'Web Designing',
#        'Project Coordination MBAPGDM Graduate',
#        'Full Stack Development Founders Office', 'MERN Stack Development',
#        'Teaching Web Development',
#        'Machine Learning  Artificial Intelligence',
#        'Project Management Interactive Division',
#        'NoSQL Database Development',
#        'Artificial Intelligence  Machine Learning Development',
#        'Electronics Instrumentation', 'Software Engineering Automation',
#        'Power BI Development', 'AndroidFlutter Development',
#        'NodeJS Development', 'DevOps', 'Desktop Engineering',
#        'Full Stack Development MEAN Stack',
#        'Associate Software Development',
#        'Embedded Systems Firmware Development',
#        'Lecture Creation Computer Science', 'Online Teaching Java',
#        'Computer Science Engineering', 'Ruby On Rails Development',
#        'Unity 3D Game Development', 'Course Development Blockchain',
#        'Technical Software Implementation', 'SAP ABAP Programming',
#        'Wix Web Development', 'QTQML Augmented Reality',
#        'Computer Vision Development', 'Technical Writing',
#        'Programming  CAD Design', 'Software Engineering',
#        'MERN Development', 'Front End Web Development',
#        'WordPress Web Development', 'React Native', 'Ethical Hacking',
#        'ReactJS Web Development', 'Full Stack Engineering ReactJS',
#        'Selenium Test Automation', 'Camera DSP Management',
#        'Web Development Wix', 'Manual Software Testing',
#        'Mobile App Development Nodejs', 'Mobile App Development Reactjs',
#        'Full Stack Development JavaNETPython',
#        'Software Development GoLang', 'Front End Engineering',
#        'Game Development', 'Research  Development Proof of Concept',
#        'System Design IoT  Robotics',
#        'Artificial IntelligenceMachine Learning IoT  Robotics',
#        'Software TestingQuality Assurance', 'Firmware Development',
#        'Skill Based Gaming', 'Back End Application Development Python',
#        'Mobile Engineering Android', 'Teaching',
#        'Subject Matter Expert Computer ScienceIT',
#        'Full Stack Development JSMEAN Stack', 'FlutterDart Development',
#        'Backend Development Algo Trading Strategy Coding',
#        'RoboticsSTEM Teaching', 'KPI Dashboard Development',
#        'Django Backend Development',
#        'Machine Learning And Python Development',
#        'Website SEO  Optimization', 'Research AIML',
#        'JavaScript Extension', 'Technical Program Management Executive',
#        'Frontend Development ReactJs', 'Technical Program Management',
#        'Python  AWS Development', 'Chatbot Development',
#        'Computer Science', 'Bootstrap Development',
#        'Embedded Linux Distro Development  Yocto',
#        'Laravel Web Development', 'Full Stack Development Golang',
#        'Front End Web Development Shopify',
#        'Full Stack Development Frontend Heavy',
#        'WordPress DesignDevelopment', 'Teach Coding Arabic',
#        'Full Stack Development MEAN Stack Angular',
#        'Software Development Java Spring Boot', 'Ionic App Development',
#        'DevOps Management', 'Web Development Front End',
#        'Mobile App Development Flutter', 'Microsoft Azure',
#        'Teaching Frontend Web Development', 'Python  Reactjs Development',
#        'Android App DevelopmentKotlin Programming Smart App Development',
#        'iOS App Development Swift', 'AWS Cloud Management',
#        'Artificial Neural Networks', 'Backend Development MERN Stack',
#        'Backend Nodejs Development', 'Software Testing QA Engineering',
#        'Angular Programming', 'Web Development WordPress',
#        'Arduino Development', 'ASPNET Development', 'Quality Assurance',
#        'DevOps AWS', 'Backend Development Nodejs  PHP',
#        'Knowledge Evangelist', 'UI Development', 'Data Extraction',
#        'PHP Development CodeIgniter', 'International Teaching Coding',
#        'Android App Testing', 'C', 'AI Engineering',
#        'System Design Engineering', 'HTML  CSS Development UI  UX Design',
#        'Power Business Intelligence Power BI Development',
#        'Ethereum Blockchain Smart Contract Solidity Development',
#        'DevOps Engineering', 'Django Rest Framework Development',
#        'DRF Development', 'Reactjs Development',
#        'AngularjsJavaScriptNodejs Development', 'UIUX Design',
#        'Digital Image Processing',
#        'Deep Learning  Computer Vision Engineering Autonomous Vehicles',
#        'DevOps Internship', 'Coding', '3D Development',
#        'Project Management Scrum', 'DatabaseOracle Development',
#        'PCB Design Assembly  Testing', 'PHP Development Laravel',
#        'Artificial Intelligence  Machine Learning',
#        'Elementor Development', 'UAV Code Development ROSROS2CPython',
#        'Unity Game Development', 'Backend Management',
#        'CSECEIT Engineering', '3D Modeling', 'PythonDjango',
#        'Project Coordination', 'AngularJS Development', 'Robotics',
#        'Software Development Engineering', 'NET  C development',
#        'ReactJS Front End Development', 'Frontend Development Angular',
#        'Python NodeJS Development', 'Frontend Development UIUX',
#        'Network Administration CCNA  IoT Network',
#        'Product Engineering Frontend Engineering',
#        'Web App Development PythonDjango', 'iOS App Development Flutter',
#        'Information Security Consulting',
#        'Operating Systems Internals Core OS',
#        'Flutter Mobile App Development',
#        'System Programming Operating System Adminstration',
#        'Cyber Security Analytics', 'Computer Vision System Development',
#        'Web Development Laravel Framework', 'Teaching Technical',
#        'Postgres Database Administration',
#        'TeachingMentoring Online Coding', 'Unity App Development',
#        'Online Teaching', 'Software Development Engineering Web',
#        'Product Engineering Backend', 'Backend Engineering',
#        'Manage Services Azure', 'Python Development And Django',
#        'DjangoWordPress Development', 'API Development',
#        'Electronics Training Coding  Robotics', 'Google App Scripts',
#        'V2V Communication Spectrum Analysis  MATLAB',
#        'Android App Development  Flutter',
#        'Backend Development Ruby on Rails',
#        'Raspberry Pi Application Development', 'Embedded Software',
#        'Deep LearningComputer Vision', 'Cloud Security Engineering',
#        'Laravel', 'Web Scraping', 'UI Development ReactJS',
#        'Machine Learning', 'AngularJSAdvanced JavaScript Development',
#        'Graphic Design Game', 'Tutoring Coding', 'NETMS BI Development',
#        'Embedded Engineering', 'DevOps Development', 'Game Testing',
#        'Subject Matter Expert CSEMCAIT', 'Django And GraphQL Development',
#        'Embedded Hardware And Software Engineering',
#        'Cyber Security Development', 'Cybersecurity  Pen Testing',
#        'Backend SDE Development', 'iOS Swift 5 App Development',
#        'Shopify Development', 'Data Analytics',
#        'Software Development IoT', 'Embedded Programming',
#        'Functional Product Consulting', 'Android  IOS Testing',
#        'Python  JavaScript Development',
#        'Technical Administration Assistance',
#        'Web Game Development JS And Matterjs', 'Teaching Python',
#        'ReactJS Development API Integration', 'Magento Development',
#        'BackEnd Development Nodejs',
#        'Google Sheet Query Writing  Dashboard Creation',
#        'Cloud Computing', 'React JS PWA Development',
#        'Full Stack Development Python  Backend',
#        'Unreal Engine Game Development', 'Nodejs  WebRTC Development',
#        'Backend Development Functional Programming',
#        'Video Solutions PhysicsComputer ScienceMechanical',
#        'Angular App Development', 'WordPress  PHP Development',
#        'Backend Development Django', 'REST API Development',
#        'ROS Development', 'Technical Content Writing',
#        'Front EndBackend Development', 'App Development Flutter',
#        'Python Market Research', 'Process Simulation Management',
#        'Augmented Reality Development', 'Python Mathematics',
#        'Python Finance', 'Embedded Software Development',
#        'Full Stack Development Python', 'Salesforce Development',
#        'Python Visualization', 'Vuejs Development',
#        'Scripting Development', 'Advanced PHP Development',
#        'Mobile App Development React Native', 'Hardware Field Testing',
#        'Full Stack Development DjangoReactJS',
#        'Linux System Administration',
#        'Hardware Engineering PrototypingTesting', 'UIUX Testing',
#        'PreSales IT', 'Python Development Django',
#        'Firmware Engineering CC',
#        'Product Development And Implementation',
#        'ReactJSReact Native Development', 'MobileWeb App Development',
#        'Application Testing',
#        'Technical Support Associate Network Firewall',
#        'Front End Development  Angular', 'C Windows Forms Development',
#        'SQL Development', 'Content Creation Linux', 'ReactJS',
#        'Product Management EdtechTalent Acquisition',
#        'Desktop Application Development', 'Teaching Assistance Java',
#        'IT Service', 'Wireless Driver Research',
#        'Teaching Online Robotics',
#        'Product Development  Prototype Engineering',
#        'Technical Operations',
#        'Video Content Development Web Development',
#        'Video Content Development Java Course',
#        'Video Online Course Development Python',
#        'Video Content Development Android App Development',
#        'Signal Processing  Wavelets',
#        'Video Content Development C Programming',
#        'ReactJS  NodeJS Development Mern Stack Development',
#        'Product Management Mobile Apps',
#        'Video Content Development Artificial Intelligence',
#        'Video Content Development Machine Learning',
#        'Networking  Administration', 'Teaching Android App Development',
#        'Teaching Ethical Hacking', 'Azure Development',
#        'Python Development Data Automation  Core Scripting',
#        'Flutter Development For PWA Progressive Web App',
#        'Battery Pack And Software Development',
#        'Full Stack Development AngularFirebase',
#        'Content Creation Python', 'Data Structure Development',
#        'ReactJS Development NET Environment',
#        'Angular 7  Nodejs Development With MongoDBFirebase',
#        'Python Automation And Scrapping',
#        'Data Science  Machine Learning',
#        'Whitepaper Management Computer Science',
#        'React Native Mobile App Development', 'QA  Project Coordination',
#        'Deep Learning AI Software Development', 'Teaching Computer',
#        'Content Management',
#        'Summer Research Intern  Artificial Intelligence',
#        'Online Teaching Coding', 'VUEjs Development',
#        'Computer Science IT', 'Web Development React',
#        'Cloud  Network Specialist', 'User Research App',
#        'Software Engineering NETDevOps', 'BackendFull Stack Development',
#        'Code Development ROSROS 2C', 'Web Development Teaching',
#        'Quality Assurance  Testing', 'Power Automate RPA',
#        'Content Writing Game Development', 'Coding Teaching',
#        'Back End DevelopmentFull Stack Development', 'Manual Testing',
#        'Teaching Python  Mathematics', 'QA Engineering',
#        'Flutter Mobile Development', 'Programming C',
#        'Quality Assurance QA', 'Game Art 3D  2D',
#        'Training MIT App DevelopmentAndroid', 'Training Cyber Security',
#        'Training Robotics', 'Kotlin Development', 'Frontend Development',
#        'Swift Development', 'Embedded Systems',
#        'Web Development WordPress And WooCommerce',
#        'Computer Vision  Deep Learning',
#        'Quality Analysis Software Development',
#        'Incident ResponseThreat IntelligenceMalware AnalysisSOC L1',
#        'MySQL Development', 'Robotics Engineering AIComputer Vision',
#        'Course Development Java Programming',
#        'Research Python Development',
#        'Technical Teaching Artificial Intelligence', 'ABAP Programming',
#        'Subject Matter Expert JavaScript', 'System Engineering IT',
#        'Information  Communication Technologies ICT',
#        'Natural Language Processing Development', 'MLOps', 'Teaching IT',
#        'Embedded Systems Engineering',
#        'Embedded Software Raspberry Pi  AI',
#        'Teaching Computer Applications', 'Teaching Software Development',
#        'PHP Laravel Development', 'ReactJS Development Frontend',
#        'IT Operations', 'Microsoft Power BI', 'GUI Development',
#        'Software Programming', 'Software Packaging',
#        'Angular Web Development', 'Systems Engineering',
#        'Full Stack Teaching PHPJS HTMLCSSJQUERY',
#        'Unity3D Application Development',
#        'PythonDjangoPostgress SQL Development', 'Heroku Development',
#        'Cloud Engineering Projects',
#        'Flutter Mobile Application Development',
#        'Huawei Cloud Software Deployment Configuration',
#        'Mobile App Testing', 'Software Tech Support',
#        'Unreal Development', 'Website Testing  Content Audit',
#        'Advanced Web Automation', 'WixWordpress Development',
#        'Advanced Web Development', 'Mobile Game Development',
#        'Teaching Python Programming', 'Research  Training Robotics',
#        'Embedded Systems Development',
#        'Project  Product Management Blockchain', 'Web Development Wixcom',
#        'Front End Development AngularUIUX', 'Support Engineering',
#        'C Development', 'IT  Web Development',
#        'System AdministrationDevOps', 'Nodejs  ReactJS Development',
#        'Summer Research', 'Academic Research Computer Science'],
#       dtype=object)

# %% [markdown]
# Step 5: Regex replace numbers or non-digit characters
#
# Now let's check how we can** replace all non digit characters and convert the value to int or remove all numbers from a column**.
#
# Replace all non numeric symbols and map in case of missing
# In this example we are going to replace everything which is not a number with a regex. In case of a value which doesn't have a number we will map the value to 0.

# %%
df['applicants'].unique()
# Out:
# array(['119', '194', '113', '183', '205', '457', '54', '618',
#        'Be an early applicant', '34', '28', '32', '41', '35', '31', '46',
#        '49', '57', '38', '43', '44', '75', '39', '37', '48', '47', '55',
#        '66', '27', '26', '52', '62', '68', '72', '50', '78', '70', '84',
#        '120', '139', '33', '45', '263', '59', '95', '36', '64', '89',
#        '86', '76', '63', '107', '143', '80', '42', '58', '127', '110',
#        '309', '91', '30', '82', '93', '85', '129', '117', '29', '60',
#        '40', '61', '51', '122', '192', '230', '102', '100', '88', '268',
#        '115', '265', '56', '87', '65', '238', '144', '69', '299', '121',
#        '233', '125', '79', '174', '155', '73', '104', '135', '156', '167',
#        '131', '164', '94', '81', '53', '71', '106', '142', '83', '178',
#        '74', '114', '96', '90', '172', '123', '103', '405', '99', '108',
#        '150', '185', '145', '202', '184', '128', '130', '147', '77',
#        '260', '134', '67', '351', '136', '379', '179', '92', '204', '242',
#        '151', '133', '305', '124', '346', '118', '140', '229', '186',
#        '97', '391', '170', '126', '256', '173', '138', '240', '161',
#        '317', '191', '111', '279', '157', '112', '364', '197', '645',
#        '482', '163', '153', '219', '211', '322', '171', '212', '324',
#        '190', '98', '105', '277', '275', '187', '398', '222', '257',
#        '214', '206', '199', '182', '116', '271', '331', '310', '154',
#        '169', '101', '334', '296', '292', '283', '162', '288', '245',
#        '177', '160', '323', '298', '254', '166', '501', '252', '208',
#        '502', '223', '225', '241', '215', '420', '341', '236', '137',
#        '352', '209', '259', '181', '377', '231', '149', '1000+', '247',
#        '220', '290', '132', '286', '246', '855', '450', '399', '598',
#        '266', '306', '203'], dtype=object)

# %%
df['ap_5']=df['applicants'].str.replace(r'\D+', '', regex=True)
df['ap_5'].unique()
# Out:
# array(['119', '194', '113', '183', '205', '457', '54', '618', '', '34',
#        '28', '32', '41', '35', '31', '46', '49', '57', '38', '43', '44',
#        '75', '39', '37', '48', '47', '55', '66', '27', '26', '52', '62',
#        '68', '72', '50', '78', '70', '84', '120', '139', '33', '45',
#        '263', '59', '95', '36', '64', '89', '86', '76', '63', '107',
#        '143', '80', '42', '58', '127', '110', '309', '91', '30', '82',
#        '93', '85', '129', '117', '29', '60', '40', '61', '51', '122',
#        '192', '230', '102', '100', '88', '268', '115', '265', '56', '87',
#        '65', '238', '144', '69', '299', '121', '233', '125', '79', '174',
#        '155', '73', '104', '135', '156', '167', '131', '164', '94', '81',
#        '53', '71', '106', '142', '83', '178', '74', '114', '96', '90',
#        '172', '123', '103', '405', '99', '108', '150', '185', '145',
#        '202', '184', '128', '130', '147', '77', '260', '134', '67', '351',
#        '136', '379', '179', '92', '204', '242', '151', '133', '305',
#        '124', '346', '118', '140', '229', '186', '97', '391', '170',
#        '126', '256', '173', '138', '240', '161', '317', '191', '111',
#        '279', '157', '112', '364', '197', '645', '482', '163', '153',
#        '219', '211', '322', '171', '212', '324', '190', '98', '105',
#        '277', '275', '187', '398', '222', '257', '214', '206', '199',
#        '182', '116', '271', '331', '310', '154', '169', '101', '334',
#        '296', '292', '283', '162', '288', '245', '177', '160', '323',
#        '298', '254', '166', '501', '252', '208', '502', '223', '225',
#        '241', '215', '420', '341', '236', '137', '352', '209', '259',
#        '181', '377', '231', '149', '1000', '247', '220', '290', '132',
#        '286', '246', '855', '450', '399', '598', '266', '306', '203'],
#       dtype=object)

# %%
df['ap_5'].sort_values().unique()
# Out:
# array(['', '100', '1000', '101', '102', '103', '104', '105', '106', '107',
#        '108', '110', '111', '112', '113', '114', '115', '116', '117',
#        '118', '119', '120', '121', '122', '123', '124', '125', '126',
#        '127', '128', '129', '130', '131', '132', '133', '134', '135',
#        '136', '137', '138', '139', '140', '142', '143', '144', '145',
#        '147', '149', '150', '151', '153', '154', '155', '156', '157',
#        '160', '161', '162', '163', '164', '166', '167', '169', '170',
#        '171', '172', '173', '174', '177', '178', '179', '181', '182',
#        '183', '184', '185', '186', '187', '190', '191', '192', '194',
#        '197', '199', '202', '203', '204', '205', '206', '208', '209',
#        '211', '212', '214', '215', '219', '220', '222', '223', '225',
#        '229', '230', '231', '233', '236', '238', '240', '241', '242',
#        '245', '246', '247', '252', '254', '256', '257', '259', '26',
#        '260', '263', '265', '266', '268', '27', '271', '275', '277',
#        '279', '28', '283', '286', '288', '29', '290', '292', '296', '298',
#        '299', '30', '305', '306', '309', '31', '310', '317', '32', '322',
#        '323', '324', '33', '331', '334', '34', '341', '346', '35', '351',
#        '352', '36', '364', '37', '377', '379', '38', '39', '391', '398',
#        '399', '40', '405', '41', '42', '420', '43', '44', '45', '450',
#        '457', '46', '47', '48', '482', '49', '50', '501', '502', '51',
#        '52', '53', '54', '55', '56', '57', '58', '59', '598', '60', '61',
#        '618', '62', '63', '64', '645', '65', '66', '67', '68', '69', '70',
#        '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81',
#        '82', '83', '84', '85', '855', '86', '87', '88', '89', '90', '91',
#        '92', '93', '94', '95', '96', '97', '98', '99'], dtype=object)

# %%
f= df['ap_5'] ==''
df[f].fillna
# Out:
# <bound method DataFrame.fillna of                                 internship  \
# 8                Quality Control & Testing
# 9             Software Support Engineering
# 10           Full Stack Development (MERN)
# 11                       Business Analysis
# 12                        Software Testing
# ...                                    ...
# 2559                Mobile App Development
# 2563                       Summer Research
# 2564  Academic Research (Computer Science)
# 2565                      Computer Science
# 2566                      Computer Science
#
#                                            company_name  \
# 8                 Veritos Infosolutions Private Limited
# 9                                                   Ori
# 10                                          Blackcoffer
# 11                                          Blackcoffer
# 12    iTalent India Management Consultants Private L...
# ...                                                 ...
# 2559                                       RVJ Infotech
# 2563  Indraprastha Institute Of Information Technolo...
# 2564                               Max Planck Institute
# 2565  Aryabhatta Research Institute Of Observational...
# 2566  Aryabhatta Research Institute Of Observational...
#
#                                              skills  \
# 8                       MS-Office, Software Testing
# 9                                               NaN
# 10    Python, MongoDB, Node.js, Express.js, ReactJS
# 11       Project Management, Research and Analytics
# 12                                 Software Testing
# ...                                             ...
# 2559                          HTML, CSS, JavaScript
# 2563                                            NaN
# 2564                                            NaN
# 2565                                            NaN
# 2566                                            NaN
#
#                                                   perks  \
# 8                                                   NaN
# 9                                                   NaN
# 10    Certificate, Letter of recommendation, Flexibl...
# 11    Certificate, Letter of recommendation, Flexibl...
# 12      Certificate, Flexible work hours, 5 days a week
# ...                                                 ...
# 2559   Certificate, Letter of recommendation, Job offer
# 2563                                                NaN
# 2564                                                NaN
# 2565                                                NaN
# 2566                                                NaN
#
#                                             location  duration  \
# 8     Ambala, Chandigarh, Ludhiana, Zirakpur, Mohali  6 Months
# 9                                              Noida  6 Months
# 10                                    Work From Home  6 Months
# 11                                    Work From Home  6 Months
# 12                                    Work From Home  4 Months
# ...                                              ...       ...
# 2559                                          Jaipur  3 Months
# 2563                                           Delhi  2 Months
# 2564                                  Work From Home  3 Months
# 2565                                        Nainital  5 Months
# 2566                                        Nainital  5 Months
#
#                 stipend             applicants  \
# 8      6000-7000 /month  Be an early applicant
# 9          15000 /month  Be an early applicant
# 10    5000-10000 /month  Be an early applicant
# 11          5000 /month  Be an early applicant
# 12     4000-6000 /month  Be an early applicant
# ...                 ...                    ...
# 2559   2000-4000 /month  Be an early applicant
# 2563        5000 /month  Be an early applicant
# 2564       Not provided  Be an early applicant
# 2565       10000 /month  Be an early applicant
# 2566       10000 /month  Be an early applicant
#
#                           ifSkillsorPerksMissingUseThis ap_5
# 8     MS-Office\nSoftware Testing, Certificate\nLett...
# 9     Certificate\nFlexible work hours\n5 days a wee...
# 10    Python\nMongoDB\nNode.js\nExpress.js\nReactJS,...
# 11    Project Management\nResearch and Analytics, Ce...
# 12    Software Testing, Certificate\nFlexible work h...
# ...                                                 ...  ...
# 2559  HTML\nCSS\nJavaScript, Certificate\nLetter of ...
# 2563                                                NaN
# 2564                                                NaN
# 2565                                                NaN
# 2566                                                NaN
#
# [1045 rows x 10 columns]>

# %%
df['ap_5'].isnull
# Out:
# <bound method Series.isnull of 0       119
# 1       194
# 2       113
# 3       183
# 4       205
#        ...
# 2562     30
# 2563
# 2564
# 2565
# 2566
# Name: ap_5, Length: 2567, dtype: object>

# %%
df['regex_1']= df['applicants'].apply(lambda x: re.findall(r'\d+', x))
df['regex_1']
# Out:
# 0       [119]
# 1       [194]
# 2       [113]
# 3       [183]
# 4       [205]
#         ...
# 2562     [30]
# 2563       []
# 2564       []
# 2565       []
# 2566       []
# Name: regex_1, Length: 2567, dtype: object

# %%
type(df['regex_1'])
# Out:
# pandas.core.series.Series

# %%
df['regex_1'].values
# Out:
# array([list(['119']), list(['194']), list(['113']), ..., list([]),
#        list([]), list([])], dtype=object)

# %%
df['regex_1'][0]
# Out:
# ['119']

# %%
df['regex_1'][0][0]
# Out:
# '119'

# %%
len(df['regex_1'])
# Out:
# 2567

# %%
df[['applicants', 'regex_1']]
# Out:
#                  applicants regex_1
# 0            119 applicants   [119]
# 1            194 applicants   [194]
# 2            113 applicants   [113]
# 3            183 applicants   [183]
# 4            205 applicants   [205]
# ...                     ...     ...
# 2562          30 applicants    [30]
# 2563  Be an early applicant      []
# 2564  Be an early applicant      []
# 2565  Be an early applicant      []
# 2566  Be an early applicant      []
#
# [2567 rows x 2 columns]

# %%
for i in range(len(df['ap_5'])):
    print(df['ap_5'][i])
# Out:
# 119
# 194
# 113
# 183
# 205
# 457
# 54
# 618
#
#
#
#
#
#
#
#
#
#
#
#
# 34
#
#
# 28
#
#
#
#
#
#
#
# 32
#
#
#
#
#
# 41
#
#
#
#
#
# 41
#
#
#
# 35
#
#
#
#
#
# 31
#
#
# 46
#
#
# 49
#
#
# 34
#
#
# 57
#
# 32
#
#
# 38
#
#
# 49
# 35
#
#
#
# 43
#
#
# 44
#
#
#
#
#
#
# 75
#
#
#
#
#
# 39
#
#
#
#
#
#
#
#
# 37
#
# 34
#
#
# 48
#
# 47
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 47
#
#
# 55
#
#
#
#
#
# 66
#
# 31
#
#
#
# 31
#
#
#
#
#
#
#
#
#
# 27
#
#
# 26
#
#
# 32
#
#
#
# 52
#
#
#
#
#
#
# 62
# 31
#
#
# 68
#
# 37
#
#
#
#
#
#
#
#
#
# 66
#
#
#
# 68
#
# 47
#
#
#
#
# 72
#
#
#
# 34
#
#
#
#
#
#
#
#
#
# 37
# 26
# 50
#
#
#
# 27
#
# 35
#
# 27
# 78
#
# 47
#
#
#
#
#
# 27
# 37
# 70
#
# 34
#
#
# 84
#
# 120
# 37
# 139
# 75
#
# 27
#
#
#
#
#
# 66
# 33
#
# 45
#
# 263
# 59
# 120
# 95
#
#
#
# 36
# 28
# 119
#
# 64
# 66
# 89
#
# 43
# 31
# 55
# 39
#
#
# 75
#
# 86
#
#
#
#
#
# 59
#
# 76
#
#
#
# 63
#
#
#
#
#
#
# 35
#
#
#
# 27
#
# 107
#
# 68
# 31
#
#
#
# 44
#
# 143
# 80
# 42
#
#
# 37
# 33
# 39
# 58
# 127
#
# 110
# 42
#
#
#
# 36
# 36
# 309
# 43
#
#
# 38
# 66
#
#
#
# 32
# 27
# 72
#
#
#
#
# 55
# 62
#
# 39
# 91
# 43
# 33
#
#
# 30
# 120
#
#
#
#
# 82
#
#
#
#
# 35
#
#
#
#
#
#
# 93
#
# 75
#
#
# 85
#
# 33
# 129
#
#
#
# 32
# 38
#
#
#
#
#
#
#
# 117
#
#
#
#
#
# 29
#
#
# 60
# 38
#
# 31
# 48
#
# 40
#
#
#
#
#
# 64
#
#
# 61
#
#
# 51
#
# 37
# 60
#
#
#
#
# 37
#
#
# 45
#
# 29
# 45
#
# 44
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 38
#
# 122
#
# 27
# 192
#
#
# 49
# 48
# 49
# 48
#
# 27
#
#
#
#
#
#
#
# 70
# 93
#
#
# 230
# 40
# 95
#
#
#
#
#
#
#
# 34
#
#
# 34
#
#
#
#
#
#
#
#
# 43
#
#
#
#
#
#
# 31
#
# 102
#
#
# 68
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 39
# 39
# 39
# 39
# 80
# 93
# 84
# 28
#
# 100
# 32
# 61
#
# 88
# 268
#
# 55
#
# 33
# 33
# 115
# 115
#
#
# 62
# 62
# 62
# 265
#
# 58
# 58
# 26
# 56
# 87
#
# 50
# 47
# 47
# 65
# 36
# 61
#
#
# 238
#
#
# 144
# 57
# 69
#
# 299
# 89
#
# 49
#
# 40
# 29
# 40
#
#
# 34
#
#
#
#
# 30
# 52
# 52
# 47
#
# 78
#
#
#
#
# 34
#
# 121
#
#
#
# 85
# 233
# 125
#
# 79
#
# 61
#
#
# 29
#
# 86
# 32
# 36
# 26
#
# 174
#
#
# 89
# 155
# 50
# 73
# 31
#
# 33
# 30
# 30
#
# 129
# 76
# 50
# 104
# 31
# 49
# 26
# 43
#
#
#
#
#
#
# 135
# 79
# 36
# 65
# 156
#
# 43
# 70
#
#
# 49
# 32
# 65
#
# 32
#
# 167
#
#
# 61
# 46
#
#
# 79
# 26
# 26
# 26
# 91
# 46
#
#
#
# 27
#
#
#
#
#
# 131
# 164
# 47
# 75
#
# 41
#
#
# 94
#
# 37
#
# 64
#
#
#
#
# 41
#
#
# 58
#
# 81
#
# 48
# 62
# 53
# 88
# 88
#
#
#
#
# 87
# 52
# 63
# 56
# 107
# 33
# 30
#
# 34
# 30
# 75
# 48
#
# 56
#
#
#
#
# 73
#
# 71
#
# 106
# 35
# 26
# 28
#
# 87
# 142
# 33
#
#
#
# 87
#
#
#
#
# 37
#
# 135
# 35
#
# 83
#
#
#
# 49
# 69
#
# 178
# 33
#
# 48
#
#
# 30
# 27
#
# 72
#
# 46
# 155
#
#
#
# 48
#
# 135
# 80
# 74
# 41
#
# 49
# 32
# 114
#
#
# 174
# 86
# 44
#
#
#
#
# 26
# 27
# 56
#
# 31
#
#
#
#
# 49
#
# 49
# 96
# 63
# 26
# 90
# 44
#
# 63
# 29
# 40
#
# 50
# 172
# 123
# 43
# 49
# 35
# 27
# 103
#
# 33
#
#
#
# 405
# 64
# 30
# 33
#
# 99
# 108
#
#
#
#
#
# 68
# 37
# 49
# 73
#
# 57
#
# 150
#
# 32
# 100
# 39
# 76
# 90
# 185
# 86
# 104
#
# 31
# 108
# 47
# 71
# 70
#
# 87
# 58
# 119
# 119
#
#
# 70
# 76
# 99
# 45
# 27
# 62
# 27
# 31
# 38
# 41
#
# 40
# 145
#
#
#
# 48
#
#
# 31
#
# 36
#
#
# 47
#
# 156
#
# 45
# 39
#
#
# 63
# 33
# 202
# 194
#
# 38
# 38
#
#
# 28
# 184
# 32
# 80
#
# 55
#
# 79
# 51
#
# 60
#
#
#
#
# 27
# 128
# 61
# 69
# 130
#
# 37
# 95
#
# 31
#
# 103
# 147
# 49
# 27
# 41
# 29
# 142
# 55
#
# 50
#
# 68
# 68
#
# 68
#
#
# 70
# 99
# 63
#
# 53
# 56
#
# 53
#
# 30
# 30
# 41
#
# 87
# 38
# 28
# 54
# 64
# 47
#
# 34
#
#
# 46
# 77
#
# 58
# 53
# 260
# 134
# 29
#
# 205
#
# 129
# 106
# 106
# 67
# 72
# 83
# 145
#
# 41
#
# 147
# 29
# 71
# 91
# 60
# 86
# 134
# 75
# 351
#
# 135
# 121
# 104
# 33
# 136
# 379
# 67
#
# 40
# 50
# 32
# 114
# 65
# 28
# 59
# 42
# 179
# 36
# 26
# 103
#
# 92
# 39
# 39
# 55
# 131
#
# 34
#
# 42
#
# 47
#
# 147
# 204
# 63
# 80
# 49
#
#
#
# 78
# 205
#
# 95
# 49
# 31
# 87
#
#
# 80
# 63
# 93
# 75
#
# 33
# 73
#
# 95
# 40
# 31
# 72
# 75
#
#
# 72
# 75
#
# 73
# 39
# 46
# 90
#
#
#
# 89
# 70
# 145
# 27
#
# 55
#
# 27
#
# 125
#
# 147
# 39
# 80
# 43
#
#
# 73
# 27
# 92
#
# 107
#
# 43
#
# 50
# 242
# 62
# 43
#
# 151
# 136
#
#
# 35
# 52
# 49
#
# 129
# 129
# 129
#
#
# 33
#
# 27
# 71
# 50
# 34
# 37
#
# 94
# 38
# 65
# 64
#
#
# 27
# 29
#
# 34
# 31
# 135
# 133
# 59
#
# 32
# 59
# 305
#
# 46
# 61
#
# 67
# 39
# 27
# 48
# 124
#
# 147
# 147
# 125
# 76
# 36
# 346
# 120
#
#
#
# 69
#
# 204
# 72
# 107
#
# 30
# 113
# 27
#
#
# 29
#
# 58
#
# 45
# 167
# 33
# 50
# 51
# 30
#
# 61
# 27
# 72
# 65
# 50
#
# 81
# 65
#
# 118
# 118
# 50
#
#
# 65
# 35
# 67
# 26
# 59
#
# 36
#
#
#
# 30
#
# 26
#
#
# 46
#
#
# 30
# 143
#
#
# 140
#
# 194
# 50
# 94
# 59
#
#
# 36
#
# 33
#
#
#
# 49
# 49
# 33
#
#
#
# 49
# 100
# 41
#
# 164
#
# 52
# 38
# 86
# 136
#
# 164
#
# 30
#
#
# 44
#
#
# 117
# 68
# 68
# 80
#
# 34
# 30
#
# 37
# 72
#
#
# 70
# 34
# 229
#
#
#
#
# 88
# 55
# 76
# 33
# 29
# 72
#
#
# 52
#
#
#
# 186
#
# 65
#
#
# 31
#
# 49
# 40
#
# 43
# 97
# 391
# 164
# 34
#
# 90
#
#
# 36
# 117
# 77
# 43
#
# 170
# 126
# 36
# 36
# 36
#
#
# 40
#
# 39
#
# 44
#
# 125
#
# 78
# 256
#
# 173
# 65
#
# 59
#
# 39
# 76
#
# 49
# 86
# 136
#
# 29
#
#
# 44
# 46
#
# 49
#
# 138
# 99
# 84
# 26
# 32
#
#
#
# 46
# 86
# 52
# 74
# 75
# 31
# 240
# 161
# 317
# 185
# 191
# 33
#
#
#
# 60
# 99
#
#
# 111
# 68
# 65
# 279
# 52
# 157
# 28
# 112
# 75
# 364
# 87
# 62
# 26
#
# 90
# 192
#
# 38
# 185
#
#
#
#
# 36
# 59
# 42
# 115
#
# 71
# 197
# 645
#
#
#
# 38
# 79
# 53
# 63
# 482
# 163
# 40
# 27
# 83
# 114
#
#
#
# 33
#
#
# 153
# 67
#
# 65
# 51
#
# 219
# 41
#
# 100
# 211
# 211
# 211
#
# 43
#
#
#
#
# 54
# 59
# 75
#
#
# 32
#
# 322
# 26
# 27
# 35
#
#
# 28
#
#
# 73
#
# 42
# 28
# 83
# 34
# 26
# 186
#
# 86
# 34
#
#
# 90
# 125
# 64
# 31
# 31
# 64
# 31
#
# 26
# 51
# 64
#
# 35
#
# 55
# 29
# 133
#
# 26
# 34
# 42
#
#
#
#
#
# 45
# 47
#
# 171
#
# 41
#
#
# 124
# 36
#
#
# 48
#
#
#
# 35
# 95
# 212
# 212
# 76
#
#
# 33
#
# 324
# 26
# 27
# 35
#
#
# 30
#
#
# 74
#
# 42
# 29
# 83
# 34
# 26
# 190
#
# 86
# 34
#
#
# 90
# 125
# 65
# 31
#
# 26
# 51
# 64
#
# 36
#
# 55
# 29
# 29
# 134
#
# 26
# 35
# 42
#
#
#
#
#
# 45
# 47
#
# 172
#
# 41
#
#
# 125
# 36
#
#
# 48
#
#
#
# 35
# 95
# 212
# 50
#
#
# 113
# 83
# 52
#
# 39
#
# 98
# 53
# 53
# 53
#
#
#
#
# 135
# 49
#
# 52
# 36
# 89
# 95
# 93
# 28
#
# 105
# 35
# 61
#
# 88
# 277
#
# 56
#
# 34
# 33
# 122
#
# 275
# 40
# 32
#
# 65
#
#
# 95
# 30
# 187
# 398
# 140
# 140
#
#
#
# 43
#
#
# 52
# 66
#
#
#
#
#
# 66
# 51
#
# 222
# 100
# 38
# 81
# 30
# 71
# 28
# 38
# 197
#
# 33
#
# 48
# 192
#
# 80
# 94
#
# 62
#
#
# 33
# 143
# 62
# 62
#
# 57
# 257
# 133
# 49
# 104
# 197
# 112
# 59
#
# 214
# 144
# 110
# 52
# 36
#
# 77
#
# 206
# 104
# 34
# 199
# 45
#
# 42
#
# 85
#
# 182
# 38
#
# 70
#
#
# 93
# 52
# 44
# 36
# 31
#
#
# 116
# 92
# 122
# 56
# 44
# 88
#
# 35
# 57
# 271
#
#
# 58
# 26
# 56
# 88
#
# 51
# 48
# 49
# 67
# 36
# 62
#
#
# 331
#
#
# 145
# 57
# 77
#
# 310
# 92
#
# 49
#
# 40
# 30
# 40
# 40
# 40
#
#
# 34
#
#
#
#
# 30
# 53
# 154
# 30
# 27
# 28
#
# 32
#
# 44
#
# 73
# 40
#
# 229
# 43
# 32
#
#
# 90
#
#
#
# 36
# 190
# 29
# 52
# 57
#
# 31
# 30
#
#
#
# 36
# 212
# 70
# 38
#
# 131
#
#
# 42
# 27
#
#
#
# 47
#
# 41
#
# 63
# 97
#
# 34
# 33
# 77
# 71
# 44
#
# 71
#
# 27
#
# 51
# 95
#
#
# 31
# 78
# 31
# 42
# 103
# 103
# 103
# 77
#
#
#
# 127
# 28
#
#
# 51
# 42
# 157
# 45
#
#
# 169
# 101
# 76
# 62
#
#
# 42
# 75
# 55
# 46
#
# 28
# 67
#
# 64
# 93
#
# 334
# 106
# 110
#
#
# 40
#
# 296
# 296
#
# 296
#
#
# 86
#
#
# 127
# 26
# 85
# 191
#
#
# 57
#
#
# 53
#
# 49
# 93
#
# 38
# 169
# 292
# 46
#
#
# 70
#
#
#
#
# 56
# 27
#
#
# 58
# 38
# 174
# 41
# 41
# 174
# 41
#
# 96
# 49
#
# 283
# 32
# 60
# 104
#
#
#
#
#
# 41
# 56
#
# 93
#
#
#
# 30
#
#
#
# 55
# 33
# 77
# 43
# 47
# 63
# 39
#
# 45
# 110
#
# 40
# 43
# 52
# 52
#
# 40
# 40
# 43
# 52
# 31
# 202
# 63
# 75
#
# 54
#
# 49
# 52
#
#
#
# 70
#
# 29
#
# 66
# 43
# 105
#
# 56
# 26
#
# 135
#
#
# 162
# 39
# 41
#
# 107
# 39
#
# 66
# 44
# 44
# 38
# 288
# 245
# 177
# 47
#
#
# 140
# 28
#
#
#
# 33
#
# 88
#
# 28
# 46
# 77
#
# 34
#
# 32
# 97
# 129
#
#
#
# 83
# 145
# 43
# 57
# 199
# 214
# 160
# 88
# 197
# 30
# 323
# 76
# 76
# 323
# 76
# 50
# 30
# 51
# 48
#
# 44
# 131
#
# 143
# 145
# 115
# 298
#
# 119
# 41
# 69
# 78
# 54
# 44
# 64
# 254
#
# 164
# 51
# 53
#
# 73
# 42
# 166
# 501
# 64
# 64
# 61
# 28
# 35
#
# 29
# 47
# 47
# 47
# 30
#
#
#
# 50
# 52
# 170
# 153
# 62
# 97
# 252
# 27
#
# 52
# 66
#
# 39
# 100
# 208
# 50
# 52
# 79
# 31
#
#
#
# 502
#
# 89
#
# 233
# 85
# 223
#
# 106
# 26
# 31
# 46
# 38
# 38
# 28
# 194
# 169
# 88
# 225
# 58
# 241
# 49
#
#
# 33
# 26
# 26
# 52
# 30
# 31
# 78
# 64
# 32
# 60
# 82
# 64
# 49
#
#
# 32
#
#
# 105
#
# 121
# 61
# 124
#
# 58
# 30
# 131
# 36
# 87
#
#
# 42
# 32
# 55
# 31
#
# 48
# 119
# 52
# 187
# 57
# 212
# 106
#
# 31
# 88
# 64
# 27
#
#
# 112
# 40
# 140
# 103
# 84
# 96
# 186
# 51
# 43
# 26
#
# 48
# 140
# 99
# 166
# 44
# 215
# 91
# 106
# 120
#
#
#
#
#
# 26
# 101
# 126
#
#
#
# 166
# 76
# 78
#
#
# 121
# 219
# 420
# 32
# 134
# 341
#
# 236
# 47
# 45
# 58
#
#
# 151
# 39
#
# 39
# 205
# 81
# 36
# 26
# 55
# 44
# 29
#
#
#
#
#
#
# 32
#
#
# 102
#
# 31
#
# 145
# 61
# 177
# 305
#
# 208
#
# 97
# 137
# 100
# 352
# 54
# 95
# 45
# 68
#
# 31
# 379
# 29
#
# 31
# 150
# 209
# 126
# 259
# 100
# 51
# 181
#
# 56
# 56
# 181
#
# 56
# 56
# 65
# 377
#
# 231
# 87
#
# 64
# 85
# 97
# 66
# 89
# 80
#
# 66
# 27
#
# 156
# 76
# 38
# 29
#
# 77
# 48
# 64
# 43
#
# 53
# 49
# 31
# 138
#
# 71
#
# 106
# 43
# 103
# 103
# 103
#
#
# 48
#
# 208
#
# 56
#
# 45
# 60
#
# 51
# 43
# 27
#
# 92
# 177
# 55
# 68
# 51
#
# 36
#
#
# 62
# 58
# 26
# 84
# 149
# 41
# 79
# 95
# 40
# 32
# 95
# 63
#
# 62
# 49
# 49
# 62
# 49
# 28
#
# 42
# 37
#
# 1000
# 66
#
#
# 51
# 70
# 91
# 55
# 129
#
# 39
# 457
#
# 26
# 125
#
#
# 247
# 178
# 220
# 74
# 222
# 283
# 290
#
# 101
# 73
# 260
# 30
#
#
# 64
# 28
# 28
#
# 132
#
#
# 334
#
# 32
# 45
#
#
# 96
#
# 40
# 286
# 91
# 42
#
# 99
# 37
# 30
# 36
# 129
# 246
# 211
#
# 855
# 105
# 134
#
#
#
# 124
# 37
# 47
# 88
# 47
# 41
#
#
#
#
# 71
# 171
# 74
#
# 106
# 133
# 94
# 129
# 450
#
#
# 52
# 27
# 29
# 95
#
#
#
# 208
# 58
# 40
#
# 46
# 35
# 72
# 399
#
# 68
# 191
# 114
# 598
#
# 31
# 55
# 103
#
#
# 49
# 132
#
#
#
# 49
# 132
#
# 191
# 56
# 266
# 306
# 203
# 79
# 79
#
# 38
# 138
# 30

# %%
from warnings import catch_warnings
import numpy as np
y=0
x=[]
for i in range(len(df['regex_1'])):
    try: 
        x.append(df['regex_1'][i][0])
    
    except:
        y=y+1

# %%
x,y
# Out:
# (['119',
#   '194',
#   '113',
#   '183',
#   '205',
#   '457',
#   '54',
#   '618',
#   '34',
#   '28',
#   '32',
#   '41',
#   '41',
#   '35',
#   '31',
#   '46',
#   '49',
#   '34',
#   '57',
#   '32',
#   '38',
#   '49',
#   '35',
#   '43',
#   '44',
#   '75',
#   '39',
#   '37',
#   '34',
#   '48',
#   '47',
#   '47',
#   '55',
#   '66',
#   '31',
#   '31',
#   '27',
#   '26',
#   '32',
#   '52',
#   '62',
#   '31',
#   '68',
#   '37',
#   '66',
#   '68',
#   '47',
#   '72',
#   '34',
#   '37',
#   '26',
#   '50',
#   '27',
#   '35',
#   '27',
#   '78',
#   '47',
#   '27',
#   '37',
#   '70',
#   '34',
#   '84',
#   '120',
#   '37',
#   '139',
#   '75',
#   '27',
#   '66',
#   '33',
#   '45',
#   '263',
#   '59',
#   '120',
#   '95',
#   '36',
#   '28',
#   '119',
#   '64',
#   '66',
#   '89',
#   '43',
#   '31',
#   '55',
#   '39',
#   '75',
#   '86',
#   '59',
#   '76',
#   '63',
#   '35',
#   '27',
#   '107',
#   '68',
#   '31',
#   '44',
#   '143',
#   '80',
#   '42',
#   '37',
#   '33',
#   '39',
#   '58',
#   '127',
#   '110',
#   '42',
#   '36',
#   '36',
#   '309',
#   '43',
#   '38',
#   '66',
#   '32',
#   '27',
#   '72',
#   '55',
#   '62',
#   '39',
#   '91',
#   '43',
#   '33',
#   '30',
#   '120',
#   '82',
#   '35',
#   '93',
#   '75',
#   '85',
#   '33',
#   '129',
#   '32',
#   '38',
#   '117',
#   '29',
#   '60',
#   '38',
#   '31',
#   '48',
#   '40',
#   '64',
#   '61',
#   '51',
#   '37',
#   '60',
#   '37',
#   '45',
#   '29',
#   '45',
#   '44',
#   '38',
#   '122',
#   '27',
#   '192',
#   '49',
#   '48',
#   '49',
#   '48',
#   '27',
#   '70',
#   '93',
#   '230',
#   '40',
#   '95',
#   '34',
#   '34',
#   '43',
#   '31',
#   '102',
#   '68',
#   '29',
#   '29',
#   '29',
#   '29',
#   '29',
#   '29',
#   '29',
#   '29',
#   '29',
#   '29',
#   '29',
#   '29',
#   '29',
#   '29',
#   '29',
#   '29',
#   '29',
#   '29',
#   '29',
#   '29',
#   '29',
#   '29',
#   '29',
#   '29',
#   '29',
#   '39',
#   '39',
#   '39',
#   '39',
#   '80',
#   '93',
#   '84',
#   '28',
#   '100',
#   '32',
#   '61',
#   '88',
#   '268',
#   '55',
#   '33',
#   '33',
#   '115',
#   '115',
#   '62',
#   '62',
#   '62',
#   '265',
#   '58',
#   '58',
#   '26',
#   '56',
#   '87',
#   '50',
#   '47',
#   '47',
#   '65',
#   '36',
#   '61',
#   '238',
#   '144',
#   '57',
#   '69',
#   '299',
#   '89',
#   '49',
#   '40',
#   '29',
#   '40',
#   '34',
#   '30',
#   '52',
#   '52',
#   '47',
#   '78',
#   '34',
#   '121',
#   '85',
#   '233',
#   '125',
#   '79',
#   '61',
#   '29',
#   '86',
#   '32',
#   '36',
#   '26',
#   '174',
#   '89',
#   '155',
#   '50',
#   '73',
#   '31',
#   '33',
#   '30',
#   '30',
#   '129',
#   '76',
#   '50',
#   '104',
#   '31',
#   '49',
#   '26',
#   '43',
#   '135',
#   '79',
#   '36',
#   '65',
#   '156',
#   '43',
#   '70',
#   '49',
#   '32',
#   '65',
#   '32',
#   '167',
#   '61',
#   '46',
#   '79',
#   '26',
#   '26',
#   '26',
#   '91',
#   '46',
#   '27',
#   '131',
#   '164',
#   '47',
#   '75',
#   '41',
#   '94',
#   '37',
#   '64',
#   '41',
#   '58',
#   '81',
#   '48',
#   '62',
#   '53',
#   '88',
#   '88',
#   '87',
#   '52',
#   '63',
#   '56',
#   '107',
#   '33',
#   '30',
#   '34',
#   '30',
#   '75',
#   '48',
#   '56',
#   '73',
#   '71',
#   '106',
#   '35',
#   '26',
#   '28',
#   '87',
#   '142',
#   '33',
#   '87',
#   '37',
#   '135',
#   '35',
#   '83',
#   '49',
#   '69',
#   '178',
#   '33',
#   '48',
#   '30',
#   '27',
#   '72',
#   '46',
#   '155',
#   '48',
#   '135',
#   '80',
#   '74',
#   '41',
#   '49',
#   '32',
#   '114',
#   '174',
#   '86',
#   '44',
#   '26',
#   '27',
#   '56',
#   '31',
#   '49',
#   '49',
#   '96',
#   '63',
#   '26',
#   '90',
#   '44',
#   '63',
#   '29',
#   '40',
#   '50',
#   '172',
#   '123',
#   '43',
#   '49',
#   '35',
#   '27',
#   '103',
#   '33',
#   '405',
#   '64',
#   '30',
#   '33',
#   '99',
#   '108',
#   '68',
#   '37',
#   '49',
#   '73',
#   '57',
#   '150',
#   '32',
#   '100',
#   '39',
#   '76',
#   '90',
#   '185',
#   '86',
#   '104',
#   '31',
#   '108',
#   '47',
#   '71',
#   '70',
#   '87',
#   '58',
#   '119',
#   '119',
#   '70',
#   '76',
#   '99',
#   '45',
#   '27',
#   '62',
#   '27',
#   '31',
#   '38',
#   '41',
#   '40',
#   '145',
#   '48',
#   '31',
#   '36',
#   '47',
#   '156',
#   '45',
#   '39',
#   '63',
#   '33',
#   '202',
#   '194',
#   '38',
#   '38',
#   '28',
#   '184',
#   '32',
#   '80',
#   '55',
#   '79',
#   '51',
#   '60',
#   '27',
#   '128',
#   '61',
#   '69',
#   '130',
#   '37',
#   '95',
#   '31',
#   '103',
#   '147',
#   '49',
#   '27',
#   '41',
#   '29',
#   '142',
#   '55',
#   '50',
#   '68',
#   '68',
#   '68',
#   '70',
#   '99',
#   '63',
#   '53',
#   '56',
#   '53',
#   '30',
#   '30',
#   '41',
#   '87',
#   '38',
#   '28',
#   '54',
#   '64',
#   '47',
#   '34',
#   '46',
#   '77',
#   '58',
#   '53',
#   '260',
#   '134',
#   '29',
#   '205',
#   '129',
#   '106',
#   '106',
#   '67',
#   '72',
#   '83',
#   '145',
#   '41',
#   '147',
#   '29',
#   '71',
#   '91',
#   '60',
#   '86',
#   '134',
#   '75',
#   '351',
#   '135',
#   '121',
#   '104',
#   '33',
#   '136',
#   '379',
#   '67',
#   '40',
#   '50',
#   '32',
#   '114',
#   '65',
#   '28',
#   '59',
#   '42',
#   '179',
#   '36',
#   '26',
#   '103',
#   '92',
#   '39',
#   '39',
#   '55',
#   '131',
#   '34',
#   '42',
#   '47',
#   '147',
#   '204',
#   '63',
#   '80',
#   '49',
#   '78',
#   '205',
#   '95',
#   '49',
#   '31',
#   '87',
#   '80',
#   '63',
#   '93',
#   '75',
#   '33',
#   '73',
#   '95',
#   '40',
#   '31',
#   '72',
#   '75',
#   '72',
#   '75',
#   '73',
#   '39',
#   '46',
#   '90',
#   '89',
#   '70',
#   '145',
#   '27',
#   '55',
#   '27',
#   '125',
#   '147',
#   '39',
#   '80',
#   '43',
#   '73',
#   '27',
#   '92',
#   '107',
#   '43',
#   '50',
#   '242',
#   '62',
#   '43',
#   '151',
#   '136',
#   '35',
#   '52',
#   '49',
#   '129',
#   '129',
#   '129',
#   '33',
#   '27',
#   '71',
#   '50',
#   '34',
#   '37',
#   '94',
#   '38',
#   '65',
#   '64',
#   '27',
#   '29',
#   '34',
#   '31',
#   '135',
#   '133',
#   '59',
#   '32',
#   '59',
#   '305',
#   '46',
#   '61',
#   '67',
#   '39',
#   '27',
#   '48',
#   '124',
#   '147',
#   '147',
#   '125',
#   '76',
#   '36',
#   '346',
#   '120',
#   '69',
#   '204',
#   '72',
#   '107',
#   '30',
#   '113',
#   '27',
#   '29',
#   '58',
#   '45',
#   '167',
#   '33',
#   '50',
#   '51',
#   '30',
#   '61',
#   '27',
#   '72',
#   '65',
#   '50',
#   '81',
#   '65',
#   '118',
#   '118',
#   '50',
#   '65',
#   '35',
#   '67',
#   '26',
#   '59',
#   '36',
#   '30',
#   '26',
#   '46',
#   '30',
#   '143',
#   '140',
#   '194',
#   '50',
#   '94',
#   '59',
#   '36',
#   '33',
#   '49',
#   '49',
#   '33',
#   '49',
#   '100',
#   '41',
#   '164',
#   '52',
#   '38',
#   '86',
#   '136',
#   '164',
#   '30',
#   '44',
#   '117',
#   '68',
#   '68',
#   '80',
#   '34',
#   '30',
#   '37',
#   '72',
#   '70',
#   '34',
#   '229',
#   '88',
#   '55',
#   '76',
#   '33',
#   '29',
#   '72',
#   '52',
#   '186',
#   '65',
#   '31',
#   '49',
#   '40',
#   '43',
#   '97',
#   '391',
#   '164',
#   '34',
#   '90',
#   '36',
#   '117',
#   '77',
#   '43',
#   '170',
#   '126',
#   '36',
#   '36',
#   '36',
#   '40',
#   '39',
#   '44',
#   '125',
#   '78',
#   '256',
#   '173',
#   '65',
#   '59',
#   '39',
#   '76',
#   '49',
#   '86',
#   '136',
#   '29',
#   '44',
#   '46',
#   '49',
#   '138',
#   '99',
#   '84',
#   '26',
#   '32',
#   '46',
#   '86',
#   '52',
#   '74',
#   '75',
#   '31',
#   '240',
#   '161',
#   '317',
#   '185',
#   '191',
#   '33',
#   '60',
#   '99',
#   '111',
#   '68',
#   '65',
#   '279',
#   '52',
#   '157',
#   '28',
#   '112',
#   '75',
#   '364',
#   '87',
#   '62',
#   '26',
#   '90',
#   '192',
#   '38',
#   '185',
#   '36',
#   '59',
#   '42',
#   '115',
#   '71',
#   '197',
#   '645',
#   '38',
#   '79',
#   '53',
#   '63',
#   '482',
#   '163',
#   '40',
#   '27',
#   '83',
#   '114',
#   '33',
#   '153',
#   '67',
#   '65',
#   '51',
#   '219',
#   '41',
#   '100',
#   '211',
#   '211',
#   '211',
#   '43',
#   '54',
#   '59',
#   '75',
#   '32',
#   '322',
#   '26',
#   '27',
#   '35',
#   '28',
#   '73',
#   '42',
#   '28',
#   '83',
#   '34',
#   '26',
#   '186',
#   '86',
#   '34',
#   '90',
#   '125',
#   '64',
#   '31',
#   '31',
#   '64',
#   '31',
#   '26',
#   '51',
#   '64',
#   '35',
#   '55',
#   '29',
#   '133',
#   '26',
#   '34',
#   '42',
#   '45',
#   '47',
#   '171',
#   '41',
#   '124',
#   '36',
#   '48',
#   '35',
#   '95',
#   '212',
#   '212',
#   '76',
#   '33',
#   '324',
#   '26',
#   '27',
#   '35',
#   '30',
#   '74',
#   '42',
#   '29',
#   '83',
#   '34',
#   '26',
#   '190',
#   '86',
#   '34',
#   '90',
#   '125',
#   '65',
#   '31',
#   '26',
#   '51',
#   '64',
#   '36',
#   '55',
#   '29',
#   '29',
#   '134',
#   '26',
#   '35',
#   '42',
#   '45',
#   '47',
#   '172',
#   '41',
#   '125',
#   '36',
#   '48',
#   '35',
#   '95',
#   '212',
#   '50',
#   '113',
#   '83',
#   '52',
#   '39',
#   '98',
#   '53',
#   '53',
#   '53',
#   '135',
#   '49',
#   '52',
#   '36',
#   '89',
#   '95',
#   '93',
#   '28',
#   '105',
#   '35',
#   '61',
#   '88',
#   '277',
#   '56',
#   '34',
#   '33',
#   '122',
#   '275',
#   '40',
#   '32',
#   '65',
#   '95',
#   '30',
#   '187',
#   '398',
#   '140',
#   '140',
#   '43',
#   '52',
#   '66',
#   '66',
#   '51',
#   '222',
#   '100',
#   '38',
#   '81',
#   '30',
#   '71',
#   '28',
#   '38',
#   '197',
#   '33',
#   '48',
#   '192',
#   '80',
#   '94',
#   '62',
#   '33',
#   '143',
#   '62',
#   '62',
#   '57',
#   '257',
#   '133',
#   '49',
#   '104',
#   '197',
#   '112',
#   '59',
#   '214',
#   '144',
#   '110',
#   '52',
#   '36',
#   '77',
#   '206',
#   '104',
#   '34',
#   '199',
#   '45',
#   '42',
#   '85',
#   '182',
#   '38',
#   '70',
#   '93',
#   '52',
#   '44',
#   '36',
#   '31',
#   '116',
#   '92',
#   '122',
#   '56',
#   '44',
#   '88',
#   '35',
#   '57',
#   '271',
#   '58',
#   '26',
#   '56',
#   '88',
#   '51',
#   '48',
#   '49',
#   '67',
#   '36',
#   '62',
#   '331',
#   '145',
#   '57',
#   '77',
#   '310',
#   '92',
#   '49',
#   '40',
#   '30',
#   ...],
#  1045)
